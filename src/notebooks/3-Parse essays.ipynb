# %%
from time import time_ns
import os

from PIL import Image
import pandas as pd
import numpy as np
import glob

# %%
ESSAYS_DIR = '../../data/1_initial/redacoes/enem/2021'
FORM_PATH = '../../data/1_initial/forms/2021.csv'
FORM_EXAM_TYPE = 'Enem'
IMAGE_TYPES = ('*.png', '*.jpg', '*.jpeg', '*.tif', '*.tiff')
MANUAL_REVISION_DIR = '../../data/2_intermediate/redacoes/enem/2021'
OUTPUT_PATH = '../../data/3_manually_processed/redacoes/enem/2021.csv'

# %%
# def get_correct_aspect_image_indices(images, expected_ratio, threshold):
#     indices = []
#     for i, image in enumerate(images):
#         aspect_ratio = float(image.width)/float(image.height)
#         if abs(aspect_ratio-expected_ratio) < threshold:
#             indices.append(i)
#     return indices

# %%
images = []
for type_ in IMAGE_TYPES:
    image_path = os.path.join(ESSAYS_DIR, type_)
    images.extend(glob.glob(image_path))
images.sort(key=os.path.getmtime)
print(len(images))
print(images)
# Out:
# 17
# ['../../data/1_initial/redacoes/enem/2021/redacao - Carolina Rocha Falvo.jpg', '../../data/1_initial/redacoes/enem/2021/redacao - Adkuesley Ferreira da Silva.tif', '../../data/1_initial/redacoes/enem/2021/redacao - Gabriela Boal.tif', '../../data/1_initial/redacoes/enem/2021/redacao - Breno Luca Teles da Silva.tif', '../../data/1_initial/redacoes/enem/2021/redacao - Sabrina Ferreira dos Santos.tif', '../../data/1_initial/redacoes/enem/2021/redacao - Maisa do Nascimento Urbano.tif', '../../data/1_initial/redacoes/enem/2021/redacaoENEM2021 - Juliana Cristina Luiz Cordeiro.tiff', '../../data/1_initial/redacoes/enem/2021/redacao - Thaina Xavier de Andrade.tif', '../../data/1_initial/redacoes/enem/2021/redacao enem - Gabriel Fuitem Martins.png', '../../data/1_initial/redacoes/enem/2021/redacao - Joao Guilherme Alves Santos.tif', '../../data/1_initial/redacoes/enem/2021/redacao - Cassio Azevedo Cancio.tif', '../../data/1_initial/redacoes/enem/2021/redacao (1) - Flavia de Brito Feitosa.tif', '../../data/1_initial/redacoes/enem/2021/redacao (1) - Rogério Guilherme USP.tif', '../../data/1_initial/redacoes/enem/2021/57927D47-19AF-4BA5-BBEC-B57586C69E15 - Giovanna Lia Iglesias.jpeg', '../../data/1_initial/redacoes/enem/2021/redacao - Luis Felipe Santana de Almeida e Silva.tif', '../../data/1_initial/redacoes/enem/2021/Enem_2020 - Arthur Salvador de Almeida.jpg', '../../data/1_initial/redacoes/enem/2021/redacao - Julia da Costa Aguiar.tif']

# %%
form = pd.read_csv(FORM_PATH).convert_dtypes()
exam_mask = form['Forma de ingresso'].str.contains('Enem')
essay_mask = np.logical_not(form['Envie aqui o espelho da sua redação.1'].isna())
exam_essays = form.loc[np.logical_and(exam_mask, essay_mask)]
exam_essays
# Out:
#     Carimbo de data/hora          Cidade Unidade Curso Unidade.1  \
# 394  29/03/2021 16:27:11       São Paulo    <NA>  <NA>      <NA>
# 539  05/04/2021 21:58:23       São Paulo    <NA>  <NA>      <NA>
# 650  12/04/2021 20:39:09       São Paulo    <NA>  <NA>      <NA>
# 838  29/05/2021 15:36:06  Ribeirão Preto    <NA>  <NA>      <NA>
# 840  29/05/2021 20:31:59       São Paulo    <NA>  <NA>      <NA>
# 842  31/05/2021 10:18:31       São Paulo    <NA>  <NA>      <NA>
# 846  04/06/2021 11:53:52       São Paulo    <NA>  <NA>      <NA>
# 847  06/06/2021 20:00:22       São Paulo    <NA>  <NA>      <NA>
# 854  21/06/2021 15:48:18       São Paulo    <NA>  <NA>      <NA>
# 857  23/06/2021 17:34:30       São Paulo    <NA>  <NA>      <NA>
# 859  23/06/2021 17:50:17       São Paulo    <NA>  <NA>      <NA>
# 873  13/07/2021 01:57:12       São Paulo    <NA>  <NA>      <NA>
# 876  04/08/2021 10:19:20          Lorena    <NA>  <NA>       EEL
# 880  19/08/2021 13:11:52      São Carlos    <NA>  <NA>      <NA>
# 882  24/08/2021 12:33:32       São Paulo    <NA>  <NA>      <NA>
# 896  29/09/2021 14:21:54       São Paulo    <NA>  <NA>      <NA>
# 919  20/12/2021 18:45:25       São Paulo    <NA>  <NA>      <NA>
#
#                 Curso.1 Unidade.2 Curso.2 Unidade.3 Curso.3  ...  \
# 394                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 539                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 650                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 838                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 840                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 842                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 846                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 847                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 854                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 857                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 859                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 873                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 876  Engenharia Química      <NA>    <NA>      <NA>    <NA>  ...
# 880                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 882                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 896                <NA>      <NA>    <NA>      <NA>    <NA>  ...
# 919                <NA>      <NA>    <NA>      <NA>    <NA>  ...
#
#     Nota na Competência 2  Nota na Competência 3 Nota na Competência 4  \
# 394                   200                    200                   200
# 539                   180                    160                   180
# 650                   180                    160                   160
# 838                   200                    200                   200
# 840                   200                    160                   200
# 842                   200                    180                   200
# 846                   200                    200                   200
# 847                   200                    180                   180
# 854                   200                    200                   200
# 857                   180                    180                   200
# 859                   200                    180                   200
# 873                   200                    180                   200
# 876                   120                    160                   120
# 880                   180                    200                   180
# 882                   120                    140                   160
# 896                   200                    200                   200
# 919                   200                    200                   180
#
#     Nota na Competência 5              Envie aqui o espelho da sua redação.1  \
# 394                   200  https://drive.google.com/open?id=1OWcisZ_cYUSV...
# 539                   180  https://drive.google.com/open?id=1yBPpGKsTl8fL...
# 650                   160  https://drive.google.com/open?id=1F6uo6hs_WlQa...
# 838                   200  https://drive.google.com/open?id=1FRusMbMtIc7v...
# 840                   200  https://drive.google.com/open?id=15lrQ2UrnIYMM...
# 842                   200  https://drive.google.com/open?id=19XPfGilB3hNe...
# 846                   180  https://drive.google.com/open?id=1mpZb-YuUqvg9...
# 847                   200  https://drive.google.com/open?id=1_CL18m-WQT_f...
# 854                   200  https://drive.google.com/open?id=1aI3B0BfuBnBj...
# 857                   200  https://drive.google.com/open?id=1rWtcQd8G9xHz...
# 859                   200  https://drive.google.com/open?id=1hm-soLc1Dirj...
# 873                   200  https://drive.google.com/open?id=1URSraRPBd22j...
# 876                   120  https://drive.google.com/open?id=1SPGhfebcJATT...
# 880                   180  https://drive.google.com/open?id=1iSn0DmwVeb5x...
# 882                   180  https://drive.google.com/open?id=1Ro3cYj0X3v3X...
# 896                   200  https://drive.google.com/open?id=1C8bG_DGPZ2W1...
# 919                   200  https://drive.google.com/open?id=1RMWpOEvSWh7-...
#
#     Quais foram as medalhas que você submeteu para seu ingresso?  \
# 394                                               <NA>
# 539                                               <NA>
# 650                                               <NA>
# 838                                               <NA>
# 840                                               <NA>
# 842                                               <NA>
# 846                                               <NA>
# 847                                               <NA>
# 854                                               <NA>
# 857                                               <NA>
# 859                                               <NA>
# 873                                               <NA>
# 876                                               <NA>
# 880                                               <NA>
# 882                                               <NA>
# 896                                               <NA>
# 919                                               <NA>
#
#     Você quer que contatemos você?  \
# 394                            Não
# 539                            Não
# 650                            Não
# 838                            Sim
# 840                            Não
# 842                            Não
# 846                            Sim
# 847                            Sim
# 854                            Não
# 857                            Não
# 859                            Sim
# 873                            Não
# 876                            Não
# 880                            Não
# 882                            Sim
# 896                            Não
# 919                            Sim
#
#     Digite um email para entrarmos em contato se quiser  \
# 394                                               <NA>
# 539                                               <NA>
# 650                                               <NA>
# 838                                  brenoteles@usp.br
# 840                                               <NA>
# 842                                               <NA>
# 846                             julianacordeiro@usp.br
# 847                               drade.real@gmail.com
# 854                              gabriel.fuitem@usp.br
# 857                                               <NA>
# 859                           cassio.acancio@gmail.com
# 873                                               <NA>
# 876                            rogerioguilherme@usp.br
# 880                                               <NA>
# 882                            luisfelipeluis49@usp.br
# 896                                               <NA>
# 919                                 juliaaguiar@usp.br
#
#        Deixe aqui qualquer comentário que quiser fazer  \
# 394                                               <NA>
# 539                                               <NA>
# 650                                               <NA>
# 838                                               <NA>
# 840                                               <NA>
# 842                                               <NA>
# 846          vocês estão fazendo um trabalho incrivel!
# 847  queria ter conhecido o site enquanto estava es...
# 854                                               <NA>
# 857                                               <NA>
# 859                                               <NA>
# 873                                               <NA>
# 876                                               <NA>
# 880                                               <NA>
# 882                                               <NA>
# 896                                               <NA>
# 919                                               <NA>
#
#     Qual o seu ano de ingresso?
# 394                        2020
# 539                        2020
# 650                        2020
# 838                        2021
# 840                        2021
# 842                        2021
# 846                        2021
# 847                        2021
# 854                        2021
# 857                        2021
# 859                        2021
# 873                        2021
# 876                        2020
# 880                        2018
# 882                        2021
# 896                        2021
# 919                        2021
#
# [17 rows x 73 columns]

# %%
def parse_enem_essays(row):
    return pd.Series({
        'ano':  row['Qual o seu ano de ingresso?'],
        'nota': row['Redação'],
        'c1':   row['Nota na Competência 1'],
        'c2':   row['Nota na Competência 2'],
        'c3':   row['Nota na Competência 3'],
        'c4':   row['Nota na Competência 4'],
        'c5':   row['Nota na Competência 5'],
    })

enem_essays_processed = exam_essays.apply(parse_enem_essays,
                                          axis=1)
enem_essays_processed
# Out:
#       ano  nota   c1   c2   c3   c4   c5
# 394  2020   980  180  200  200  200  200
# 539  2020   840  140  180  160  180  180
# 650  2020   820  160  180  160  160  160
# 838  2021   980  180  200  200  200  200
# 840  2021   920  160  200  160  200  200
# 842  2021   940  160  200  180  200  200
# 846  2021   920  140  200  200  200  180
# 847  2021   920  160  200  180  180  200
# 854  2021   980  180  200  200  200  200
# 857  2021   940  180  180  180  200  200
# 859  2021   940  160  200  180  200  200
# 873  2021   940  160  200  180  200  200
# 876  2020   660  140  120  160  120  120
# 880  2018   920  180  180  200  180  180
# 882  2021   760  160  120  140  160  180
# 896  2021   960  160  200  200  200  200
# 919  2021   940  160  200  200  180  200

# %%
def parse_fuvest_essays(row):
    return pd.Series({
        'ano':  row['Qual o seu ano de ingresso?'],
        'nota': row['Nota da redação'],
    })

fuvest_essays_processed = exam_essays.apply(parse_fuvest_essays,
                                            axis=1)
fuvest_essays_processed

# %%
expected_ratio = 0.74
threshold = 0.025
normalised_crop_height = 0.1977
no_header_dir = 'no_header'
manual_revision_dir = 'manual'
exam_essays_processed = enem_essays_processed

os.makedirs('manual', exist_ok=True)
os.makedirs('no_header', exist_ok=True)

for i, image_path in enumerate(images):
    with Image.open(image_path).convert('RGB') as image:
        image_np = np.array(image)
        aspect_ratio = float(image.width)/float(image.height)

        if abs(aspect_ratio-expected_ratio) < threshold :
            crop_height = int(normalised_crop_height * image.height)
            image_no_header = image_np[crop_height:,:]
            image_path = os.path.join(no_header_dir, str(time_ns())+'.png')
            new_image = Image.fromarray(image_no_header)
            new_image.save(image_path)
        else:
            essay_information_str = list(map(str, exam_essays_processed.iloc[i]))
            image_filename = '-'.join(essay_information_str) + '_' + str(time_ns())
            image_path = os.path.join(manual_revision_dir, image_filename+'.png')
            image.save(image_path)

# %%
# !rm -r manual

# %%
# !rm -r no_header

# %%
from io import BytesIO

from google.oauth2 import service_account
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from googleapiclient.http import MediaIoBaseUpload

# %%
def upload_share_png_bytes(filename, bytes_):
    SCOPES = ['https://www.googleapis.com/auth/drive']
    SERVICE_ACCOUNT_FILE = 'service.json'
    credentials = service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)

    try:
        service = build('drive', 'v3', credentials=credentials)
        file_metadata = {'name': filename}
        media = MediaIoBaseUpload(bytes_, mimetype='image/png')
        file = service.files().create(body=file_metadata,
                                      media_body=media,
                                      fields='id').execute()

        permissions = {'type': 'anyone', 'role': 'reader'}
        service.permissions().create(
            fileId=file['id'],
            body=permissions).execute()

        return file['id']

    except HttpError as error:
        # TODO(developer) - Handle errors from drive API.
        print(f'An error occurred: {error}')

# %%
def parse_images(image_paths, expected_ratio, threshold, normalised_crop_height,
                 manual_revision_dir,
                 processed_exam_df,
                 base_view_url):

    final_info_list = []
    for i, image_path in enumerate(image_paths):
        with Image.open(image_path).convert('RGB') as image:
            aspect_ratio = float(image.width)/float(image.height)
            essay_info_series = processed_exam_df.iloc[i]

            if abs(aspect_ratio-expected_ratio) < threshold :
                crop_height = int(normalised_crop_height * image.height)
                image_no_header = np.array(image)[crop_height:,:]
                new_image = Image.fromarray(image_no_header)

                image_bytes_object = BytesIO()
                new_image.save(image_bytes_object, 'PNG')
                drive_id = upload_share_png_bytes(str(time_ns())+'.png', image_bytes_object)

                essay_info_series['drive_id'] = drive_id
                essay_info_series['url'] = base_view_url.format(drive_id)
                final_info_list.append(essay_info_series)
            else:
                essay_information_str = list(map(str, essay_info_series))
                image_filename = '-'.join(essay_information_str) + '_' + str(time_ns())
                image_path = os.path.join(manual_revision_dir, image_filename+'.png')
                image.save(image_path)

    final_info_df = pd.concat(final_info_list, axis=1).T
    return final_info_df

# %%
EXPECTED_RATIO = 0.74
THRESHOLD = 0.025
NORMALISED_CROP_HEIGHT = 0.1977
DRIVE_VIEW_BASE_URL = 'https://drive.google.com/file/d/{}/view'
info_df = parse_images(images, EXPECTED_RATIO, THRESHOLD, NORMALISED_CROP_HEIGHT,
                       MANUAL_REVISION_DIR,
                       enem_essays_processed,
                       DRIVE_VIEW_BASE_URL)
info_df
# Out:
#       ano nota   c1   c2   c3   c4   c5                           drive_id  \
# 394  2020  980  180  200  200  200  200  1cwqtAmVzEmV0IzBcvAr9QezH7MjUgHcF
# 539  2020  840  140  180  160  180  180  1m526zzzAR0KcYI2Y2o5bCCHXAiysV9F8
# 650  2020  820  160  180  160  160  160  1ZVALeAnYxOqqnAe2Vt2JlUpOfCjIQkOp
# 838  2021  980  180  200  200  200  200  1TiLakiML9k0x7LGpQh69yqFYEPYDBEpS
# 840  2021  920  160  200  160  200  200  114wpRG2vpPXsi-_oWu3T7iamcCHlledF
# 842  2021  940  160  200  180  200  200  1YdOys0aBm9ZJvTwBXVkMR2Dt7Tx_fhGg
# 847  2021  920  160  200  180  180  200  1S1oSJ2SWuVatCSnwrCvMPbWtjD8_PQBc
# 857  2021  940  180  180  180  200  200  1wqdGAjSxxQgfdhkTLaYQMeNBtTAne3CV
# 859  2021  940  160  200  180  200  200  1U9HdVZr11EtPXX0Y1Z8cVsSPKLV24_W_
# 873  2021  940  160  200  180  200  200  19acd7zWYTzFQME3otPJheoPu01He4Ocn
# 876  2020  660  140  120  160  120  120  1rZWD5yrcsR35tK3bzpZY-sCgjP074VoB
# 896  2021  960  160  200  200  200  200  1hokIHwjrd4cIfhchfARGYg0o0K2mDgea
# 919  2021  940  160  200  200  180  200  1Ltxa6YhHde1S1vNlo4FSIkU0PQSRzHd7
#
#                                                    url
# 394  https://drive.google.com/file/d/1cwqtAmVzEmV0I...
# 539  https://drive.google.com/file/d/1m526zzzAR0KcY...
# 650  https://drive.google.com/file/d/1ZVALeAnYxOqqn...
# 838  https://drive.google.com/file/d/1TiLakiML9k0x7...
# 840  https://drive.google.com/file/d/114wpRG2vpPXsi...
# 842  https://drive.google.com/file/d/1YdOys0aBm9ZJv...
# 847  https://drive.google.com/file/d/1S1oSJ2SWuVatC...
# 857  https://drive.google.com/file/d/1wqdGAjSxxQgfd...
# 859  https://drive.google.com/file/d/1U9HdVZr11EtPX...
# 873  https://drive.google.com/file/d/19acd7zWYTzFQM...
# 876  https://drive.google.com/file/d/1rZWD5yrcsR35t...
# 896  https://drive.google.com/file/d/1hokIHwjrd4cIf...
# 919  https://drive.google.com/file/d/1Ltxa6YhHde1S1...

# %%
info_df.url
# Out:
# 394    https://drive.google.com/file/d/1cwqtAmVzEmV0I...
# 539    https://drive.google.com/file/d/1m526zzzAR0KcY...
# 650    https://drive.google.com/file/d/1ZVALeAnYxOqqn...
# 838    https://drive.google.com/file/d/1TiLakiML9k0x7...
# 840    https://drive.google.com/file/d/114wpRG2vpPXsi...
# 842    https://drive.google.com/file/d/1YdOys0aBm9ZJv...
# 847    https://drive.google.com/file/d/1S1oSJ2SWuVatC...
# 857    https://drive.google.com/file/d/1wqdGAjSxxQgfd...
# 859    https://drive.google.com/file/d/1U9HdVZr11EtPX...
# 873    https://drive.google.com/file/d/19acd7zWYTzFQM...
# 876    https://drive.google.com/file/d/1rZWD5yrcsR35t...
# 896    https://drive.google.com/file/d/1hokIHwjrd4cIf...
# 919    https://drive.google.com/file/d/1Ltxa6YhHde1S1...
# Name: url, dtype: object

# %%
for i in range(info_df.shape[0]):
    print(info_df.url.iloc[i])
# Out:
# https://drive.google.com/file/d/1cwqtAmVzEmV0IzBcvAr9QezH7MjUgHcF/view
# https://drive.google.com/file/d/1m526zzzAR0KcYI2Y2o5bCCHXAiysV9F8/view
# https://drive.google.com/file/d/1ZVALeAnYxOqqnAe2Vt2JlUpOfCjIQkOp/view
# https://drive.google.com/file/d/1TiLakiML9k0x7LGpQh69yqFYEPYDBEpS/view
# https://drive.google.com/file/d/114wpRG2vpPXsi-_oWu3T7iamcCHlledF/view
# https://drive.google.com/file/d/1YdOys0aBm9ZJvTwBXVkMR2Dt7Tx_fhGg/view
# https://drive.google.com/file/d/1S1oSJ2SWuVatCSnwrCvMPbWtjD8_PQBc/view
# https://drive.google.com/file/d/1wqdGAjSxxQgfdhkTLaYQMeNBtTAne3CV/view
# https://drive.google.com/file/d/1U9HdVZr11EtPXX0Y1Z8cVsSPKLV24_W_/view
# https://drive.google.com/file/d/19acd7zWYTzFQME3otPJheoPu01He4Ocn/view
# https://drive.google.com/file/d/1rZWD5yrcsR35tK3bzpZY-sCgjP074VoB/view
# https://drive.google.com/file/d/1hokIHwjrd4cIfhchfARGYg0o0K2mDgea/view
# https://drive.google.com/file/d/1Ltxa6YhHde1S1vNlo4FSIkU0PQSRzHd7/view

# %%
info_df.to_csv(OUTPUT_PATH, index=None)
