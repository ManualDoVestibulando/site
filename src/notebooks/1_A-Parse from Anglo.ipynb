# %%
import pandas as pd

# %%
FORM_PATH = '/home/tomaz/Desktop/MDV/anglo.csv'
RESULT_PATH = '/home/tomaz/Desktop/MDV/anglo_processed.csv'

VACCANCIES_PATH = '../../data/4_final/vagas/2022.csv'

# %% [markdown]
# ## Reformatting Anglo's data

# %%
anglo_raw = pd.read_csv(FORM_PATH)
anglo_raw
# Out:
#       id  ACERTOS NA 1ª FASE  NOTA NA 2ª FASE (1º DIA)  \
# 0     72                  80                      81.5
# 1     72                  64                      70.5
# 2     72                  60                      60.5
# 3     72                  68                      63.5
# 4     72                  75                      59.0
# ..   ...                 ...                       ...
# 191   64                  81                      59.0
# 192  153                  74                      54.5
# 193  177                  65                      45.0
# 194  160                  79                      51.0
# 195  172                  63                      50.5
#
#      NOTA NA 2ª FASE (2º DIA)  NOTA FINAL  REDAÇÃO  PHE MODALIDADE  \
# 0                       75.00      817.96     45.0  NaN         AC
# 1                       76.67      727.59     38.0  NaN         AC
# 2                       57.50      615.56     38.0  NaN         EP
# 3                       72.50      705.19     33.0  NaN         AC
# 4                       77.50      732.78     41.0  NaN         AC
# ..                        ...         ...      ...  ...        ...
# 191                     90.83      799.44     30.0  NaN         AC
# 192                     71.67      694.63     29.5  NaN        NaN
# 193                     48.33      551.85     28.5  NaN         AC
# 194                     75.83      715.37     23.0  NaN         AC
# 195                     70.83      637.78     27.0  NaN         AC
#
#      CLASSIFICAÇÃO NA CARREIRA NA MODALIDADE DE INGRESSO
# 0                                                  1.0
# 1                                                 25.0
# 2                                                 15.0
# 3                                                 45.0
# 4                                                 22.0
# ..                                                 ...
# 191                                               66.0
# 192                                                NaN
# 193                                               14.0
# 194                                                1.0
# 195                                               30.0
#
# [196 rows x 9 columns]

# %%
anglo_raw.columns
# Out:
# Index(['id', 'ACERTOS NA 1ª FASE', 'NOTA NA 2ª FASE (1º DIA)',
#        'NOTA NA 2ª FASE (2º DIA)', 'NOTA FINAL', 'REDAÇÃO', 'PHE',
#        'MODALIDADE', 'CLASSIFICAÇÃO NA CARREIRA NA MODALIDADE DE INGRESSO'],
#       dtype='object')

# %%
def parse_fuvest_results(row):

    return pd.Series({
        'id':                     row['id'],
        'ano':                    2022,
        'modalidade':             row['MODALIDADE'],
        'chamada':                'Primeira',
        'nota_1':                 row['ACERTOS NA 1ª FASE'],
        'nota_2_1':               row['NOTA NA 2ª FASE (1º DIA)'],
        'nota_2_2':               row['NOTA NA 2ª FASE (2º DIA)'],
        'nota_final':             row['NOTA FINAL'],
        'nota_redacao':           row['REDAÇÃO'],
        'classificacao_carreira': pd.NA,
        'classificacao_curso':    row['CLASSIFICAÇÃO NA CARREIRA NA MODALIDADE DE INGRESSO'],
        'redacao':                pd.NA,
    })

anglo_data = anglo_raw.apply(parse_fuvest_results, axis=1)
anglo_data.head()
# Out:
#    id   ano modalidade   chamada  nota_1  nota_2_1  nota_2_2  nota_final  \
# 0  72  2022         AC  Primeira      80      81.5     75.00      817.96
# 1  72  2022         AC  Primeira      64      70.5     76.67      727.59
# 2  72  2022         EP  Primeira      60      60.5     57.50      615.56
# 3  72  2022         AC  Primeira      68      63.5     72.50      705.19
# 4  72  2022         AC  Primeira      75      59.0     77.50      732.78
#
#    nota_redacao classificacao_carreira  classificacao_curso redacao
# 0          45.0                   <NA>                  1.0    <NA>
# 1          38.0                   <NA>                 25.0    <NA>
# 2          38.0                   <NA>                 15.0    <NA>
# 3          33.0                   <NA>                 45.0    <NA>
# 4          41.0                   <NA>                 22.0    <NA>

# %%
anglo_data.isna().sum()
# Out:
# id                          0
# ano                         0
# modalidade                  5
# chamada                     0
# nota_1                      0
# nota_2_1                    0
# nota_2_2                    0
# nota_final                  0
# nota_redacao                0
# classificacao_carreira    196
# classificacao_curso         5
# redacao                   196
# dtype: int64

# %%
filter = anglo_data.modalidade.isna() | anglo_data.classificacao_curso.isna()
anglo_data.loc[filter][['modalidade', 'classificacao_curso']]
# Out:
#     modalidade  classificacao_curso
# 70         NaN                  NaN
# 78         NaN                  NaN
# 83         NaN                  NaN
# 139        NaN                  NaN
# 192        NaN                  NaN

# %%
clean_anglo_data = anglo_data.dropna(thresh=9)
clean_anglo_data
# Out:
#       id   ano modalidade   chamada  nota_1  nota_2_1  nota_2_2  nota_final  \
# 0     72  2022         AC  Primeira      80      81.5     75.00      817.96
# 1     72  2022         AC  Primeira      64      70.5     76.67      727.59
# 2     72  2022         EP  Primeira      60      60.5     57.50      615.56
# 3     72  2022         AC  Primeira      68      63.5     72.50      705.19
# 4     72  2022         AC  Primeira      75      59.0     77.50      732.78
# ..   ...   ...        ...       ...     ...       ...       ...         ...
# 190   64  2022         AC  Primeira      77      75.5     93.33      847.96
# 191   64  2022         AC  Primeira      81      59.0     90.83      799.44
# 193  177  2022         AC  Primeira      65      45.0     48.33      551.85
# 194  160  2022         AC  Primeira      79      51.0     75.83      715.37
# 195  172  2022         AC  Primeira      63      50.5     70.83      637.78
#
#      nota_redacao classificacao_carreira  classificacao_curso redacao
# 0            45.0                   <NA>                  1.0    <NA>
# 1            38.0                   <NA>                 25.0    <NA>
# 2            38.0                   <NA>                 15.0    <NA>
# 3            33.0                   <NA>                 45.0    <NA>
# 4            41.0                   <NA>                 22.0    <NA>
# ..            ...                    ...                  ...     ...
# 190          38.0                   <NA>                 13.0    <NA>
# 191          30.0                   <NA>                 66.0    <NA>
# 193          28.5                   <NA>                 14.0    <NA>
# 194          23.0                   <NA>                  1.0    <NA>
# 195          27.0                   <NA>                 30.0    <NA>
#
# [191 rows x 12 columns]

# %%
clean_anglo_data.isna().sum()
# Out:
# id                          0
# ano                         0
# modalidade                  0
# chamada                     0
# nota_1                      0
# nota_2_1                    0
# nota_2_2                    0
# nota_final                  0
# nota_redacao                0
# classificacao_carreira    191
# classificacao_curso         0
# redacao                   191
# dtype: int64

# %%
full_modalidade_dict = {
    'EP': 'Escola Pública (EP)',
    'AC': 'Ampla Concorrência (AC)',
    'PPI': 'Pretos, Pardos e Indígenas (PPI)',
}

clean_anglo_data.modalidade.replace(full_modalidade_dict, inplace=True)
clean_anglo_data
# Out:
# /tmp/ipykernel_4686/145152157.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_anglo_data.modalidade.replace(full_modalidade_dict, inplace=True)
#       id   ano               modalidade   chamada  nota_1  nota_2_1  nota_2_2  \
# 0     72  2022  Ampla Concorrência (AC)  Primeira      80      81.5     75.00
# 1     72  2022  Ampla Concorrência (AC)  Primeira      64      70.5     76.67
# 2     72  2022      Escola Pública (EP)  Primeira      60      60.5     57.50
# 3     72  2022  Ampla Concorrência (AC)  Primeira      68      63.5     72.50
# 4     72  2022  Ampla Concorrência (AC)  Primeira      75      59.0     77.50
# ..   ...   ...                      ...       ...     ...       ...       ...
# 190   64  2022  Ampla Concorrência (AC)  Primeira      77      75.5     93.33
# 191   64  2022  Ampla Concorrência (AC)  Primeira      81      59.0     90.83
# 193  177  2022  Ampla Concorrência (AC)  Primeira      65      45.0     48.33
# 194  160  2022  Ampla Concorrência (AC)  Primeira      79      51.0     75.83
# 195  172  2022  Ampla Concorrência (AC)  Primeira      63      50.5     70.83
#
#      nota_final  nota_redacao classificacao_carreira  classificacao_curso  \
# 0        817.96          45.0                   <NA>                  1.0
# 1        727.59          38.0                   <NA>                 25.0
# 2        615.56          38.0                   <NA>                 15.0
# 3        705.19          33.0                   <NA>                 45.0
# 4        732.78          41.0                   <NA>                 22.0
# ..          ...           ...                    ...                  ...
# 190      847.96          38.0                   <NA>                 13.0
# 191      799.44          30.0                   <NA>                 66.0
# 193      551.85          28.5                   <NA>                 14.0
# 194      715.37          23.0                   <NA>                  1.0
# 195      637.78          27.0                   <NA>                 30.0
#
#     redacao
# 0      <NA>
# 1      <NA>
# 2      <NA>
# 3      <NA>
# 4      <NA>
# ..      ...
# 190    <NA>
# 191    <NA>
# 193    <NA>
# 194    <NA>
# 195    <NA>
#
# [191 rows x 12 columns]

# %% [markdown]
# ## Adding MDV course information

# %%
vaccancies = pd.read_csv(VACCANCIES_PATH)
vaccancies
# Out:
#       id      campus unidade area  \
# 0      0   São Paulo    EACH    E
# 1      1   São Paulo    EACH    E
# 2      2   São Paulo    EACH    E
# 3      3   São Paulo    EACH    B
# 4      4   São Paulo    EACH    B
# ..   ...         ...     ...  ...
# 172  172   São Paulo      IQ    E
# 173  173  São Carlos    IQSC    E
# 174  174   São Paulo     IRI    H
# 175  175   São Paulo     IRI    H
# 176  177   São Paulo      IF    E
#
#                                                  curso  fuvest_ac  fuvest_ep  \
# 0                Bacharelado em Sistemas de Informação         28         10
# 1                Bacharelado em Sistemas de Informação         56         21
# 2                 Licenciatura em Ciências da Natureza         30          9
# 3               Bacharelado em Educação Física e Saúde         20         14
# 4                         Bacharelado em Biotecnologia         30         11
# ..                                                 ...        ...        ...
# 172  Química – Bacharelado e Licenciatura – Noturno...         22         12
# 173  Química Bacharelado (Hab. Fundamental e Hab. T...         24         12
# 174             Bacharelado em Relações Internacionais         14          5
# 175             Bacharelado em Relações Internacionais         14          5
# 176                       Bacharelado em Física Médica         12          4
#
#      fuvest_ppi  fuvest  enem_ac  enem_ep_l1  enem_ep_l3  enem_ep  \
# 0             4      42        2         0.0         8.0      8.0
# 1             7      84        4         0.0        16.0     16.0
# 2             3      42        0         0.0         9.0      9.0
# 3             8      42       10         4.0         0.0      4.0
# 4             1      42        0         0.0         7.0      7.0
# ..          ...     ...      ...         ...         ...      ...
# 172           8      42        8         2.0         4.0      6.0
# 173           6      42        6         3.0         3.0      6.0
# 174           2      21        1         3.0         1.0      4.0
# 175           2      21        1         3.0         1.0      4.0
# 176           1      17        0         NaN         NaN      NaN
#
#      enem_ppi_l2  enem_ppi_l4  enem_ppi  enem
# 0            0.0          8.0       8.0  18.0
# 1            0.0         16.0      16.0  36.0
# 2            0.0          9.0       9.0  18.0
# 3            4.0          0.0       4.0  18.0
# 4            0.0         11.0      11.0  18.0
# ..           ...          ...       ...   ...
# 172          2.0          2.0       4.0  18.0
# 173          3.0          3.0       6.0  18.0
# 174          3.0          1.0       4.0   9.0
# 175          3.0          1.0       4.0   9.0
# 176          NaN          NaN       NaN   NaN
#
# [177 rows x 17 columns]

# %%
full_anglo_data = vaccancies[['id', 'unidade', 'curso']].merge(clean_anglo_data,
                                                               on='id',
                                                               validate='1:m')
full_anglo_data
# Out:
#       id unidade                                   curso   ano  \
# 0      4    EACH            Bacharelado em Biotecnologia  2022
# 1      4    EACH            Bacharelado em Biotecnologia  2022
# 2      6    EACH       Curso de Graduação em Obstetrícia  2022
# 3     13    EACH            Gestão de Políticas Públicas  2022
# 4     14    EACH                               Marketing  2022
# ..   ...     ...                                     ...   ...
# 186  174     IRI  Bacharelado em Relações Internacionais  2022
# 187  175     IRI  Bacharelado em Relações Internacionais  2022
# 188  175     IRI  Bacharelado em Relações Internacionais  2022
# 189  175     IRI  Bacharelado em Relações Internacionais  2022
# 190  177      IF            Bacharelado em Física Médica  2022
#
#                   modalidade   chamada  nota_1  nota_2_1  nota_2_2  \
# 0    Ampla Concorrência (AC)  Primeira      69     54.50     53.33
# 1    Ampla Concorrência (AC)  Primeira      68     41.00     61.67
# 2        Escola Pública (EP)  Primeira      51     56.50     34.17
# 3    Ampla Concorrência (AC)  Primeira      54     43.00     45.00
# 4    Ampla Concorrência (AC)  Primeira      77     52.50     55.00
# ..                       ...       ...     ...       ...       ...
# 186  Ampla Concorrência (AC)  Primeira      81     72.50     70.83
# 187  Ampla Concorrência (AC)  Primeira      71     64.50     64.17
# 188  Ampla Concorrência (AC)  Primeira      76     65.50     57.50
# 189  Ampla Concorrência (AC)  Primeira      79     63.17     62.50
# 190  Ampla Concorrência (AC)  Primeira      65     45.00     48.33
#
#      nota_final  nota_redacao classificacao_carreira  classificacao_curso  \
# 0        615.00         34.50                   <NA>                 24.0
# 1        594.07         28.00                   <NA>                 28.0
# 2        491.11         29.50                   <NA>                  8.0
# 3        493.33         30.00                   <NA>                 46.0
# 4        643.52         31.50                   <NA>                  1.0
# ..          ...           ...                    ...                  ...
# 186      777.78         38.00                   <NA>                  3.0
# 187      691.85         38.00                   <NA>                 25.0
# 188      691.48         34.00                   <NA>                 26.0
# 189      711.48         34.67                   <NA>                 15.0
# 190      551.85         28.50                   <NA>                 14.0
#
#     redacao
# 0      <NA>
# 1      <NA>
# 2      <NA>
# 3      <NA>
# 4      <NA>
# ..      ...
# 186    <NA>
# 187    <NA>
# 188    <NA>
# 189    <NA>
# 190    <NA>
#
# [191 rows x 14 columns]

# %%
full_anglo_data.to_csv(RESULT_PATH, index=None)
