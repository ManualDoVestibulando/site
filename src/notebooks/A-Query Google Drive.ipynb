# %%
import pandas as pd

# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %% [markdown]
# ## Support functions

# %%
def run_on_drive_api(func):
    def wrapper(*args, **kwargs):
        try:
            service = build('drive', 'v3',
                            developerKey='AIzaSyBU7WIsMv5LvRD3xt8ZnV5fqfMY40iEHS8')
            return func(*args, service=service, **kwargs)
        except HttpError as error:
            print(f'An error occurred:\n\n{error}')
    return wrapper

# %%
def is_essay_file(drive_item):
    return any(x in drive_item['mimeType'] for x in ['image', 'pdf'])

# %%
@run_on_drive_api
def recreate_file_tree(initial_folder_id, service=None):
    query = f"'{initial_folder_id}' in parents"
    results = service.files().list(q=query).execute()
    items = results.get('files')
    file_items = {}

    for item in items:
        if item['mimeType'] == 'application/vnd.google-apps.folder':
            file_items[item['name']] = recreate_file_tree(item['id'])
        else:
            file_items[item['name']] = item

    return file_items

# %%
file_items = recreate_file_tree('1NxxkhOfH4eB0v6E0leGtG5hHo2amYKmG')
file_items
# Out:
# {'Fuvest': {'50.pdf': {'kind': 'drive#file',
#    'id': '1SziOtl8xeATY3cfA2VXf9NRLK0-b3ENg',
#    'name': '50.pdf',
#    'mimeType': 'application/pdf'},
#   '2018': {'36,5_309.jpg': {'kind': 'drive#file',
#     'id': '1ThLLNWnUHgGq55ElFVUFVysSem8o83HY',
#     'name': '36,5_309.jpg',
#     'mimeType': 'image/jpeg'},
#    '33 _310.jpg': {'kind': 'drive#file',
#     'id': '1J6c8CNdx6Yy1ye0gK8DLo1Oo3yUL3DLK',
#     'name': '33 _310.jpg',
#     'mimeType': 'image/jpeg'}},
#   '2020': {'red_fuvest.py': {'kind': 'drive#file',
#     'id': '1Q3ELr5i0oSzvptc_l9CgMB8kYPH2uFFb',
#     'name': 'red_fuvest.py',
#     'mimeType': 'text/x-python'},
#    '38,5-Red64 (Small).png': {'kind': 'drive#file',
#     'id': '1pJ5_z-00dpX4mbsPSzUsLX4pKFuWE434',
#     'name': '38,5-Red64 (Small).png',
#     'mimeType': 'image/png'},
#    '42,0-Red74 (Small).png': {'kind': 'drive#file',
#     'id': '1p2WISpPRTiRxxb8uzyyf3Qbkd2OgkaiS',
#     'name': '42,0-Red74 (Small).png',
#     'mimeType': 'image/png'},
#    '43,0_32 (Small).png': {'kind': 'drive#file',
#     'id': '1y0lhK2DInBrNr29fNcmR1jUo3SZKhjZU',
#     'name': '43,0_32 (Small).png',
#     'mimeType': 'image/png'},
#    '36,0_132 (Small).png': {'kind': 'drive#file',
#     'id': '1TfSZM1FeuLh6E7JrKkV1TJK5yP52_6kE',
#     'name': '36,0_132 (Small).png',
#     'mimeType': 'image/png'},
#    '40,0_179.png': {'kind': 'drive#file',
#     'id': '1SO1z8emVH0090Jy3M2gZyclmaY5kBgUu',
#     'name': '40,0_179.png',
#     'mimeType': 'image/png'},
#    '24,0_56.png': {'kind': 'drive#file',
#     'id': '1O-60tD35Gkso-MXyir5cuu9xVX_HoLSY',
#     'name': '24,0_56.png',
#     'mimeType': 'image/png'},
#    '28,0_70.png': {'kind': 'drive#file',
#     'id': '18K5YG2PZadDoLAYyN5_nbNWFsS7SL8O_',
#     'name': '28,0_70.png',
#     'mimeType': 'image/png'},
#    '35,0_79.png': {'kind': 'drive#file',
#     'id': '1KfxICvWaiHlWUsgoiwtivWAeaklbeg4k',
#     'name': '35,0_79.png',
#     'mimeType': 'image/png'},
#    '25,33-Red18.png': {'kind': 'drive#file',
#     'id': '174fBuhMjO4oXoOUGC37bV5fOQDnTPPo6',
#     'name': '25,33-Red18.png',
#     'mimeType': 'image/png'},
#    '27,0_103.png': {'kind': 'drive#file',
#     'id': '1F3qIpMT4TJLcMva_5lE9QkKF813MBINS',
#     'name': '27,0_103.png',
#     'mimeType': 'image/png'},
#    '31,5-Red62.png': {'kind': 'drive#file',
#     'id': '1JyZnBvWhKIftfTmjYI-hizjZ_rAfUfvU',
#     'name': '31,5-Red62.png',
#     'mimeType': 'image/png'},
#    '43,0_34.png': {'kind': 'drive#file',
#     'id': '1lUqkoPG8fTZjBTWfTLOtJUbEoY-Ov6CJ',
#     'name': '43,0_34.png',
#     'mimeType': 'image/png'},
#    '37,5_308.png': {'kind': 'drive#file',
#     'id': '1yghJTUJ58p-eZkPL3RYRaQLtRsdRjjGn',
#     'name': '37,5_308.png',
#     'mimeType': 'image/png'},
#    '33,0-Red68.png': {'kind': 'drive#file',
#     'id': '17tUcVOVo75kIKtlnv5nAneVY7Wnix2gf',
#     'name': '33,0-Red68.png',
#     'mimeType': 'image/png'},
#    '41,0_5.png': {'kind': 'drive#file',
#     'id': '1ztTOUORNIol_GspXt7HYvVPZnEzzCM9x',
#     'name': '41,0_5.png',
#     'mimeType': 'image/png'},
#    '35,0-Red59.png': {'kind': 'drive#file',
#     'id': '1qTb8ija0OF7NvpCuH_thMT1ltxM5a3jp',
#     'name': '35,0-Red59.png',
#     'mimeType': 'image/png'},
#    '32,0-Red21.png': {'kind': 'drive#file',
#     'id': '1CMstjUf9Mbn0Cjx0PPeqrr1g3TU597r9',
#     'name': '32,0-Red21.png',
#     'mimeType': 'image/png'},
#    '36,0_13.png': {'kind': 'drive#file',
#     'id': '1P8SXMCtxaIFgCUGRFL7dlevMWsubkEv0',
#     'name': '36,0_13.png',
#     'mimeType': 'image/png'},
#    '27,0_166.png': {'kind': 'drive#file',
#     'id': '1qHEhsdeZXtB7EKVa-N9FBiQ5VirKLf1u',
#     'name': '27,0_166.png',
#     'mimeType': 'image/png'},
#    '31,5-Red50.png': {'kind': 'drive#file',
#     'id': '1jqvfqLAL3YCiY7VJmuEQZA7E-G0TCQyY',
#     'name': '31,5-Red50.png',
#     'mimeType': 'image/png'},
#    '36,0_14.png': {'kind': 'drive#file',
#     'id': '1xQ4ZnC-9tvuHWcF8mep2EF9XMpQuoPLY',
#     'name': '36,0_14.png',
#     'mimeType': 'image/png'},
#    '31,0-Red41.png': {'kind': 'drive#file',
#     'id': '1gKPJ4sV9sMHPazERQyzYwe-NSzL3PFHM',
#     'name': '31,0-Red41.png',
#     'mimeType': 'image/png'},
#    '38,0_25.png': {'kind': 'drive#file',
#     'id': '1AxeaJ1OVX6d36-1iXAAJSVYt-M6vPSCy',
#     'name': '38,0_25.png',
#     'mimeType': 'image/png'},
#    '37,0_54.png': {'kind': 'drive#file',
#     'id': '1oKD1yQWrn-c0YbcwnErykqihmc86nuaV',
#     'name': '37,0_54.png',
#     'mimeType': 'image/png'},
#    '28,0_86.png': {'kind': 'drive#file',
#     'id': '1lxwZhtNpfwaJcikWqOCLXi8JeoZtdXuy',
#     'name': '28,0_86.png',
#     'mimeType': 'image/png'},
#    '40,0_139.png': {'kind': 'drive#file',
#     'id': '1D5qTaD1T7LWVW9DRHj3WE1E8tuf5iUWS',
#     'name': '40,0_139.png',
#     'mimeType': 'image/png'},
#    '36,0_100.png': {'kind': 'drive#file',
#     'id': '1ANarfeHVnrnc9lZGNI-GkTKEo-nZXUsY',
#     'name': '36,0_100.png',
#     'mimeType': 'image/png'},
#    '37,0_120.png': {'kind': 'drive#file',
#     'id': '1DvYkSk6txSBphyyf-LugVd2_sk7aU24f',
#     'name': '37,0_120.png',
#     'mimeType': 'image/png'},
#    '36,0_65.png': {'kind': 'drive#file',
#     'id': '1QLfaC-ORxFjAAQS97rnTknKd_UlUcvQa',
#     'name': '36,0_65.png',
#     'mimeType': 'image/png'},
#    '37,0_104.png': {'kind': 'drive#file',
#     'id': '1b2_NHueMksrS643UmquQM1xg1ubrGw-3',
#     'name': '37,0_104.png',
#     'mimeType': 'image/png'},
#    '36,5_303.png': {'kind': 'drive#file',
#     'id': '1gvqE2DET00-8HdxcXnjQLHn0lgj2KNUy',
#     'name': '36,5_303.png',
#     'mimeType': 'image/png'},
#    '34,5-Red26.png': {'kind': 'drive#file',
#     'id': '1snnTeY9DyvtxhLQX5I8jjGRfFgQ0KWMF',
#     'name': '34,5-Red26.png',
#     'mimeType': 'image/png'},
#    '32,0-Red28.png': {'kind': 'drive#file',
#     'id': '1psyJ3hAeDuF9g9LJGe9SXupBCJ4_-Zlo',
#     'name': '32,0-Red28.png',
#     'mimeType': 'image/png'},
#    '36,0-Red72.png': {'kind': 'drive#file',
#     'id': '1jxa30qBgiZQZIWEyQaZn-tFRxhfH01gC',
#     'name': '36,0-Red72.png',
#     'mimeType': 'image/png'},
#    '35,0-Red44.png': {'kind': 'drive#file',
#     'id': '1ZjLFxQs5UaP7Z7xhWSPXyzGb55OKqF6P',
#     'name': '35,0-Red44.png',
#     'mimeType': 'image/png'},
#    '36,0-Red20.png': {'kind': 'drive#file',
#     'id': '13wK5ias_1-v60uDk1hxiSiMaimfAD519',
#     'name': '36,0-Red20.png',
#     'mimeType': 'image/png'},
#    '30,0-Red57.png': {'kind': 'drive#file',
#     'id': '1SkieOzAc90q9tbjPlomDuwVt4vtZ3OJY',
#     'name': '30,0-Red57.png',
#     'mimeType': 'image/png'},
#    '40,0_164.png': {'kind': 'drive#file',
#     'id': '1lN8ZM84GOAY3S6qQ7-JbDsmDAA0XZwSw',
#     'name': '40,0_164.png',
#     'mimeType': 'image/png'},
#    '26,0_171.png': {'kind': 'drive#file',
#     'id': '1zIbppHWBr8PAPW6VY-8c09x3RVHeeosa',
#     'name': '26,0_171.png',
#     'mimeType': 'image/png'},
#    '36,0-Red40.png': {'kind': 'drive#file',
#     'id': '1B_00FsKdPeNroNwLmVdslFya5URcXGIQ',
#     'name': '36,0-Red40.png',
#     'mimeType': 'image/png'},
#    '31,5-Red60.png': {'kind': 'drive#file',
#     'id': '1RQhWlS5uhlCbEewmhPkboTZeyfZlXChu',
#     'name': '31,5-Red60.png',
#     'mimeType': 'image/png'},
#    '28,0_141.png': {'kind': 'drive#file',
#     'id': '1u1KXQ03znKCw4Ay2HwRi95sMPoQM8pFf',
#     'name': '28,0_141.png',
#     'mimeType': 'image/png'},
#    '37,0_96.png': {'kind': 'drive#file',
#     'id': '1rz_K2waPUZPymrX6697AE8AaKbzyXadP',
#     'name': '37,0_96.png',
#     'mimeType': 'image/png'},
#    '37,0_16.png': {'kind': 'drive#file',
#     'id': '1HU6nlw1L7vf1EgsjRKwrtDA0s2yOL0Zm',
#     'name': '37,0_16.png',
#     'mimeType': 'image/png'},
#    '35,0_31.png': {'kind': 'drive#file',
#     'id': '1PT9NUeNILW1EptKi6e_fPBiLbcnk1lQH',
#     'name': '35,0_31.png',
#     'mimeType': 'image/png'},
#    '36,0_95.png': {'kind': 'drive#file',
#     'id': '1E1kNBWEA4ra4yL5X6FNlWos8kfLe2fN8',
#     'name': '36,0_95.png',
#     'mimeType': 'image/png'},
#    '42,0_80.png': {'kind': 'drive#file',
#     'id': '1PiPYbF4W4j-eYxNWEANgriZlTEBA7q9b',
#     'name': '42,0_80.png',
#     'mimeType': 'image/png'},
#    '35,0_6.png': {'kind': 'drive#file',
#     'id': '1lvUc5y9TaRNmyIRU4ZL2-cY7NqIrKq4w',
#     'name': '35,0_6.png',
#     'mimeType': 'image/png'},
#    '41,0_155.png': {'kind': 'drive#file',
#     'id': '1yZK8F5YfrPlNTdeYNBlCbKJL-djyupce',
#     'name': '41,0_155.png',
#     'mimeType': 'image/png'},
#    '22,0_146.png': {'kind': 'drive#file',
#     'id': '1KDlmtv4cXjOfDSLAUxTP0mPO--ZEsoYz',
#     'name': '22,0_146.png',
#     'mimeType': 'image/png'},
#    '41,0_47.png': {'kind': 'drive#file',
#     'id': '1uKRG24rWzPrDVQSwGQcDIdGWcyI6ZBry',
#     'name': '41,0_47.png',
#     'mimeType': 'image/png'},
#    '41,0_160.png': {'kind': 'drive#file',
#     'id': '19DHOfANUEoYpqnWW41loIe0ltc5yuGbh',
#     'name': '41,0_160.png',
#     'mimeType': 'image/png'},
#    '34,5-Red29.png': {'kind': 'drive#file',
#     'id': '1LOGcVq4NgtqOk02BGbWmH8rK0TXLIGSr',
#     'name': '34,5-Red29.png',
#     'mimeType': 'image/png'},
#    '37,0_101.png': {'kind': 'drive#file',
#     'id': '1QhQSs2RC-YUTzhfuT8Dev4kyv18msS3A',
#     'name': '37,0_101.png',
#     'mimeType': 'image/png'},
#    '31,5-Red61.png': {'kind': 'drive#file',
#     'id': '1hOH6g4JOyAHwBwqVgIIJHWDJtPHU1Kkw',
#     'name': '31,5-Red61.png',
#     'mimeType': 'image/png'},
#    '33,0-Red10.png': {'kind': 'drive#file',
#     'id': '1Nmk5aKlOM-uU16RDgfTAlTWJOYxhrTzC',
#     'name': '33,0-Red10.png',
#     'mimeType': 'image/png'},
#    '25,0-Red65.png': {'kind': 'drive#file',
#     'id': '1YHD0zB0YAZpiOkWY0QuDoqMchkD2IoW9',
#     'name': '25,0-Red65.png',
#     'mimeType': 'image/png'},
#    '35,0_60.png': {'kind': 'drive#file',
#     'id': '1so0t35P_K9Qpt6HRfo-7tc9VPjwmEtsf',
#     'name': '35,0_60.png',
#     'mimeType': 'image/png'},
#    '28,5-Red55.png': {'kind': 'drive#file',
#     'id': '1UgEbSo8aO1Ta_V8POCd5LC-X89KI3uct',
#     'name': '28,5-Red55.png',
#     'mimeType': 'image/png'},
#    '37,0_117.png': {'kind': 'drive#file',
#     'id': '1Y1e9QOGa3iBRsYsD2f_OFwNmOL-ZPYcH',
#     'name': '37,0_117.png',
#     'mimeType': 'image/png'},
#    '33_306.png': {'kind': 'drive#file',
#     'id': '1QDCTgsR5gUQq3VGO0FpusIgD-u45dCiI',
#     'name': '33_306.png',
#     'mimeType': 'image/png'},
#    '34,5_305.png': {'kind': 'drive#file',
#     'id': '1zuT7F20avMwyDimt-uEVE-4PYy3fROCa',
#     'name': '34,5_305.png',
#     'mimeType': 'image/png'},
#    '43_302.png': {'kind': 'drive#file',
#     'id': '1B4JqYFFNBXoGCplKOzeL9c2Ssg85Gd01',
#     'name': '43_302.png',
#     'mimeType': 'image/png'},
#    '29,5-Red4.png': {'kind': 'drive#file',
#     'id': '12NmbewgtNJYsHgxspiaSIi_IPR2L0EGK',
#     'name': '29,5-Red4.png',
#     'mimeType': 'image/png'},
#    '37,0_15.png': {'kind': 'drive#file',
#     'id': '1psWJ7AOm0pm8pvVaP2kq-iyYR9NTDto3',
#     'name': '37,0_15.png',
#     'mimeType': 'image/png'},
#    '36,0_156.png': {'kind': 'drive#file',
#     'id': '1mc5MVJaPepkmpQDT9X_NSWKklR2_y27e',
#     'name': '36,0_156.png',
#     'mimeType': 'image/png'},
#    '43,0_52.png': {'kind': 'drive#file',
#     'id': '1ODfck0DBlc6dpVlgWUS4DVlNiRWCQwv1',
#     'name': '43,0_52.png',
#     'mimeType': 'image/png'},
#    '25,0-Red71.png': {'kind': 'drive#file',
#     'id': '1ytUwfO5SkHR00_4zRbAZ6QI27qU439d4',
#     'name': '25,0-Red71.png',
#     'mimeType': 'image/png'},
#    '35,0_97.png': {'kind': 'drive#file',
#     'id': '19nOxuzmrocaAZksAdvpj8bnPECTYCur5',
#     'name': '35,0_97.png',
#     'mimeType': 'image/png'},
#    '35,0_26.png': {'kind': 'drive#file',
#     'id': '1L4hBgNzSAmW7jiIX02j-5r0lxAezNdoD',
#     'name': '35,0_26.png',
#     'mimeType': 'image/png'},
#    '35,0_9.png': {'kind': 'drive#file',
#     'id': '1TXpuOLeFd66gXCCPxOGP4fQuQXs0aZvg',
#     'name': '35,0_9.png',
#     'mimeType': 'image/png'},
#    '35,0_153.png': {'kind': 'drive#file',
#     'id': '1QKId-X34qioAZmfz_JEeBH-MpQfGkdUg',
#     'name': '35,0_153.png',
#     'mimeType': 'image/png'},
#    '42,0_111.png': {'kind': 'drive#file',
#     'id': '1ImxyI53w4Kbk54lt5LH16iHh-pQ6Dese',
#     'name': '42,0_111.png',
#     'mimeType': 'image/png'},
#    '36,5_304.png': {'kind': 'drive#file',
#     'id': '1xQozkp2UKTZLbY38skc3br9_BCjdko4-',
#     'name': '36,5_304.png',
#     'mimeType': 'image/png'},
#    '36,0_44.png': {'kind': 'drive#file',
#     'id': '1T8hKJleMpnhnYFuTsi4_PK8h6BEzblYV',
#     'name': '36,0_44.png',
#     'mimeType': 'image/png'},
#    '29,0_112.png': {'kind': 'drive#file',
#     'id': '1ihvdjaFFXlmFcLvopmJRgUExzjSAxITy',
#     'name': '29,0_112.png',
#     'mimeType': 'image/png'},
#    '41,0_85.png': {'kind': 'drive#file',
#     'id': '1Dl541SU4b2LYbS9hX9dvEJD569M5C1Ft',
#     'name': '41,0_85.png',
#     'mimeType': 'image/png'},
#    '24,0_43.png': {'kind': 'drive#file',
#     'id': '1IX0_rWVmTQVt2s7uvmE76CCdc2OSV8zt',
#     'name': '24,0_43.png',
#     'mimeType': 'image/png'},
#    '29,33_307.png': {'kind': 'drive#file',
#     'id': '1LX0H4UVOVYCZTL9P4hyLKKSY6oOA_F0A',
#     'name': '29,33_307.png',
#     'mimeType': 'image/png'},
#    '36,0-Red14.png': {'kind': 'drive#file',
#     'id': '19fx0MraCkUHh9ZWPb1GieEryHxb9T7LT',
#     'name': '36,0-Red14.png',
#     'mimeType': 'image/png'},
#    '28,0_66.png': {'kind': 'drive#file',
#     'id': '10dVu3Id8jBux_F1-WQuPe2yPCpp7cNTZ',
#     'name': '28,0_66.png',
#     'mimeType': 'image/png'},
#    '33,0_93.png': {'kind': 'drive#file',
#     'id': '1tXybqwO4tzRTwbb3xCz9eUhH3Bih0gJG',
#     'name': '33,0_93.png',
#     'mimeType': 'image/png'},
#    '40,0-Red17.png': {'kind': 'drive#file',
#     'id': '1l3b5AfSPWl0_fmv1gTAxZ7R79vAyKeCq',
#     'name': '40,0-Red17.png',
#     'mimeType': 'image/png'},
#    '41,5-Red23.png': {'kind': 'drive#file',
#     'id': '10o4b_Oax0nWD4SiG4xIB8EsD9hvv-bxg',
#     'name': '41,5-Red23.png',
#     'mimeType': 'image/png'},
#    '30,0_144.png': {'kind': 'drive#file',
#     'id': '142N-Oy1HW6iOyaQYUiJbGJBxcZsQC9Bi',
#     'name': '30,0_144.png',
#     'mimeType': 'image/png'},
#    '39,5-Red27.png': {'kind': 'drive#file',
#     'id': '1LDsMllu2aiDPzz7MWoEY2oeb7ltEOcUf',
#     'name': '39,5-Red27.png',
#     'mimeType': 'image/png'},
#    '33,0_143.png': {'kind': 'drive#file',
#     'id': '1JM3CFcru-yytVBjHF_O41FL-Lf6OCE0X',
#     'name': '33,0_143.png',
#     'mimeType': 'image/png'},
#    '32,0_118.png': {'kind': 'drive#file',
#     'id': '1K_UnPjrLQL3xyDILbGFbtXkQMO1pIHjF',
#     'name': '32,0_118.png',
#     'mimeType': 'image/png'},
#    '34,0_75.png': {'kind': 'drive#file',
#     'id': '1Ht3H-nRm2LzKE5w4cSs1GqLrCn9b_KZy',
#     'name': '34,0_75.png',
#     'mimeType': 'image/png'},
#    '33,0_58.png': {'kind': 'drive#file',
#     'id': '1DGpmwCv2U7gWPlDAtq6TXmeyFiNS6phZ',
#     'name': '33,0_58.png',
#     'mimeType': 'image/png'},
#    '38,5-Red49.png': {'kind': 'drive#file',
#     'id': '1ITNlfnhzGaHnTzXGXNXDUQjwfoLvr0LT',
#     'name': '38,5-Red49.png',
#     'mimeType': 'image/png'},
#    '33,0_172.png': {'kind': 'drive#file',
#     'id': '17687Il-_ghG4OXfV2kY_Cugl-mE0oW3q',
#     'name': '33,0_172.png',
#     'mimeType': 'image/png'},
#    '40,0-Red7.png': {'kind': 'drive#file',
#     'id': '1JHJRAWwLz7VeYRhfjaz8ml6o4awUOoWP',
#     'name': '40,0-Red7.png',
#     'mimeType': 'image/png'},
#    '40,0-Red51.png': {'kind': 'drive#file',
#     'id': '1lwsKGMtiSZtqW4ROnSf9EaJLbdPkOUCB',
#     'name': '40,0-Red51.png',
#     'mimeType': 'image/png'},
#    '40,0-Red9.png': {'kind': 'drive#file',
#     'id': '16SBPdG7T3bMNiJG5S5KypD_Ig_2v9Mq-',
#     'name': '40,0-Red9.png',
#     'mimeType': 'image/png'},
#    '41,0-Red36.png': {'kind': 'drive#file',
#     'id': '1yraRK3VurU7RBWnNMEmjTgSXtNq9MlCZ',
#     'name': '41,0-Red36.png',
#     'mimeType': 'image/png'},
#    '37,33-Red25.png': {'kind': 'drive#file',
#     'id': '1pXDcUuwAlMcQD9Mov4fBzlazoxhUoSFN',
#     'name': '37,33-Red25.png',
#     'mimeType': 'image/png'},
#    '34,0_151.png': {'kind': 'drive#file',
#     'id': '10NmxvEzWJE7kW8gRt7NpgHz6IlrYsQ-3',
#     'name': '34,0_151.png',
#     'mimeType': 'image/png'},
#    '31,0_46.png': {'kind': 'drive#file',
#     'id': '1DObQNN4D3QH1RZjm3aS1f-mZzd6ou3ao',
#     'name': '31,0_46.png',
#     'mimeType': 'image/png'}},
#   '2019': {'42,0_87.png': {'kind': 'drive#file',
#     'id': '1FJioAB0y3kuTgtM4t_yJhHppiJYk0-jT',
#     'name': '42,0_87.png',
#     'mimeType': 'image/png'},
#    '35,0_42.png': {'kind': 'drive#file',
#     'id': '1pYqw42zDwE2zen8Lq46wIBvseK4SgnnB',
#     'name': '35,0_42.png',
#     'mimeType': 'image/png'},
#    '38,0_19.png': {'kind': 'drive#file',
#     'id': '1YZeE7Tu8D6cFA3F3G810Qk69lJQaXGMM',
#     'name': '38,0_19.png',
#     'mimeType': 'image/png'},
#    '33,0_45.png': {'kind': 'drive#file',
#     'id': '1NIfdooTWJL9oPcy6emafkgNhlUa2mVF-',
#     'name': '33,0_45.png',
#     'mimeType': 'image/png'},
#    '25,0_154.png': {'kind': 'drive#file',
#     'id': '1-DTvtscVuljVKI2uTXphAu-PICUbObfQ',
#     'name': '25,0_154.png',
#     'mimeType': 'image/png'},
#    '37,0_168.png': {'kind': 'drive#file',
#     'id': '1RfOT9poVYvACwFYFw_EU-L-e7sbeFjA7',
#     'name': '37,0_168.png',
#     'mimeType': 'image/png'},
#    '40,0_128.png': {'kind': 'drive#file',
#     'id': '1YXnnCZnSED7SBcYNxedR_Ian9q2TxwjW',
#     'name': '40,0_128.png',
#     'mimeType': 'image/png'},
#    '42,0_48.png': {'kind': 'drive#file',
#     'id': '10n_pkzsoMpyjdUFKF9_1zTDyPXlf-JUp',
#     'name': '42,0_48.png',
#     'mimeType': 'image/png'},
#    '41,0_115.png': {'kind': 'drive#file',
#     'id': '1JYnjsWSKlZGozjUZIb0j9CVbM1LlcthL',
#     'name': '41,0_115.png',
#     'mimeType': 'image/png'},
#    '40,0_136.png': {'kind': 'drive#file',
#     'id': '1EmEBiQVaFIkl9GVqOSRiEp4fOFi2vcz3',
#     'name': '40,0_136.png',
#     'mimeType': 'image/png'},
#    '45,0_8.png': {'kind': 'drive#file',
#     'id': '1DK1wZ-lR2UwRa2pe811NKhUckpLTci_b',
#     'name': '45,0_8.png',
#     'mimeType': 'image/png'},
#    '36,0_3.png': {'kind': 'drive#file',
#     'id': '1UN6Rk11r-a1dsC2gBg3nTBrImeS7NO84',
#     'name': '36,0_3.png',
#     'mimeType': 'image/png'},
#    '25,0_149.png': {'kind': 'drive#file',
#     'id': '1DG5_uhoRyjiXJFOCmDs07kNIY-OMDKki',
#     'name': '25,0_149.png',
#     'mimeType': 'image/png'},
#    '30,0_109.png': {'kind': 'drive#file',
#     'id': '15LYQCrDMzDo5729N-mEQRC6Od1S0Ez1p',
#     'name': '30,0_109.png',
#     'mimeType': 'image/png'},
#    '46,0_130.png': {'kind': 'drive#file',
#     'id': '1bicJTbJPb7fSEwMXeti5qOJBpvn-M6OT',
#     'name': '46,0_130.png',
#     'mimeType': 'image/png'},
#    '35_308.png': {'kind': 'drive#file',
#     'id': '13KOCrr_RqkbVTGTNaV_3r3gTLdeWkzhJ',
#     'name': '35_308.png',
#     'mimeType': 'image/png'},
#    '35,0_73.png': {'kind': 'drive#file',
#     'id': '1xSpq371TtcFOTQ43nVMifg6bdEP1oOnt',
#     'name': '35,0_73.png',
#     'mimeType': 'image/png'},
#    '48,0_129.png': {'kind': 'drive#file',
#     'id': '1pm7vmJgfny3dXAVtdxNmUVBwpmT53tFd',
#     'name': '48,0_129.png',
#     'mimeType': 'image/png'},
#    '38,0_38.png': {'kind': 'drive#file',
#     'id': '1kVxqdX3VJ8xtwAe9PF5NCdLyZC3QaWkD',
#     'name': '38,0_38.png',
#     'mimeType': 'image/png'},
#    '50,0_138.png': {'kind': 'drive#file',
#     'id': '1NAZggZamo__21wwHDm7ZKT_cnZwrdTqO',
#     'name': '50,0_138.png',
#     'mimeType': 'image/png'},
#    '30,0_163.png': {'kind': 'drive#file',
#     'id': '1BXSLhe9-JQrCIBt0hyN8iID-KT32epi3',
#     'name': '30,0_163.png',
#     'mimeType': 'image/png'},
#    '30,0-Red19.png': {'kind': 'drive#file',
#     'id': '1Rj5E0uZiFxCixLzQ-OHogBQJMHTvYoTz',
#     'name': '30,0-Red19.png',
#     'mimeType': 'image/png'},
#    '45,0_12.png': {'kind': 'drive#file',
#     'id': '1a6NtgvKTau_0icC_0Bst8A2UDJz_k6Ya',
#     'name': '45,0_12.png',
#     'mimeType': 'image/png'},
#    '40,0_20.png': {'kind': 'drive#file',
#     'id': '1K78Ybr4eKuf0QStJOyKP_sM9hSX4Qbs-',
#     'name': '40,0_20.png',
#     'mimeType': 'image/png'},
#    '35,0_113.png': {'kind': 'drive#file',
#     'id': '1AO2erMOU9oPomph09_fwXg73PO0zGuNm',
#     'name': '35,0_113.png',
#     'mimeType': 'image/png'},
#    '30,0_123.png': {'kind': 'drive#file',
#     'id': '1o6xgnuw-Oin043gSr9tl66rqjsyEfH1b',
#     'name': '30,0_123.png',
#     'mimeType': 'image/png'},
#    '40,0_7.png': {'kind': 'drive#file',
#     'id': '1QxwnC7lRJNdWG8VHcgGIFiwEgvumglDs',
#     'name': '40,0_7.png',
#     'mimeType': 'image/png'},
#    '38,0_165.png': {'kind': 'drive#file',
#     'id': '1W7ThT5NwhBw0S7ZKrt5Q0r3P0yKAkc2B',
#     'name': '38,0_165.png',
#     'mimeType': 'image/png'},
#    '47,0_18.png': {'kind': 'drive#file',
#     'id': '1B9TUmIT_23DROVS7LDyaxKV7nGgY4g7W',
#     'name': '47,0_18.png',
#     'mimeType': 'image/png'},
#    '35,0_127.png': {'kind': 'drive#file',
#     'id': '1_CvW_Kz4x0ROdP0DQcSYh_YGtjfRaA9F',
#     'name': '35,0_127.png',
#     'mimeType': 'image/png'},
#    '27,0_122.png': {'kind': 'drive#file',
#     'id': '1B3Gf7sUZh9SOANn673oAqeTX5T9-tQ7U',
#     'name': '27,0_122.png',
#     'mimeType': 'image/png'}}},
#  'Enem': {'2020': {'red-enem.py': {'kind': 'drive#file',
#     'id': '1pmCPPLfQ_t41IB9Sj8njTjmhdw771y4M',
#     'name': 'red-enem.py',
#     'mimeType': 'text/x-python'},
#    '920-160-200-160-200-200_17.png': {'kind': 'drive#file',
#     'id': '1CA5BuMVUlOGedcrzcyfSHRhuU2ksJCOk',
#     'name': '920-160-200-160-200-200_17.png',
#     'mimeType': 'image/png'},
#    '960-180-200-180-200-200_11.png': {'kind': 'drive#file',
#     'id': '1ozFxlkdFl0nkXdklVV7I75uLX0G_R_qx',
#     'name': '960-180-200-180-200-200_11.png',
#     'mimeType': 'image/png'},
#    '900-180-180-200-180-160_24.png': {'kind': 'drive#file',
#     'id': '1nxDup_a1LX1Tm61isRt8eVBNaNCDfMiR',
#     'name': '900-180-180-200-180-160_24.png',
#     'mimeType': 'image/png'},
#    '960-180-200-180-200-200_8.png': {'kind': 'drive#file',
#     'id': '1Y65pUXqvHbMKadsZCNdNWTO2YXeDrdpx',
#     'name': '960-180-200-180-200-200_8.png',
#     'mimeType': 'image/png'},
#    '860-160-200-160-180-160_35.png': {'kind': 'drive#file',
#     'id': '1E7PcM9kXvfiJ_EEZBLE5_ovssz-6KEZ8',
#     'name': '860-160-200-160-180-160_35.png',
#     'mimeType': 'image/png'},
#    '900-160-200-160-200-160_28.png': {'kind': 'drive#file',
#     'id': '1ZqEVtuIE5KCSaHtPAXR5jgnbwbhQO0qm',
#     'name': '900-160-200-160-200-160_28.png',
#     'mimeType': 'image/png'},
#    '920-160-200-200-200-160_37.png': {'kind': 'drive#file',
#     'id': '1zZ3b5xIvyz47HEKozjkyKWCmOOg6NW7B',
#     'name': '920-160-200-200-200-160_37.png',
#     'mimeType': 'image/png'},
#    '940-160-200-180-200-200_6.png': {'kind': 'drive#file',
#     'id': '1KPotKhNp7jbW8T_HmdGeqNtpnBQJWCnZ',
#     'name': '940-160-200-180-200-200_6.png',
#     'mimeType': 'image/png'},
#    '940-180-200-200-200-160_304.png': {'kind': 'drive#file',
#     'id': '1u-2ZFo57RT-3Gqkm7eX-hLwi8YHiMEdr',
#     'name': '940-180-200-200-200-160_304.png',
#     'mimeType': 'image/png'},
#    '960-180-200-200-180-200_303.png': {'kind': 'drive#file',
#     'id': '1lOw6-mysMl9F3e7wc_T1s1hj67bD3YeQ',
#     'name': '960-180-200-200-180-200_303.png',
#     'mimeType': 'image/png'},
#    '900-180-200-180-200-140_3.png': {'kind': 'drive#file',
#     'id': '1OsLZ5UFl3yywpqOCDbzRxq7PpNUO26Bl',
#     'name': '900-180-200-180-200-140_3.png',
#     'mimeType': 'image/png'},
#    '940-160-200-200-200-180_0.png': {'kind': 'drive#file',
#     'id': '1hSUOmBLESFjY27sjtwnY0LHlQihiptZr',
#     'name': '940-160-200-200-200-180_0.png',
#     'mimeType': 'image/png'},
#    '960-180-200-180-200-200_302.png': {'kind': 'drive#file',
#     'id': '1W-3RUW--SpzROf0oGXtGC2zIOXp3QGM_',
#     'name': '960-180-200-180-200-200_302.png',
#     'mimeType': 'image/png'},
#    '960-180-200-180-200-200_4.png': {'kind': 'drive#file',
#     'id': '1F3s3MFVNS-CHPNTaxx-Fb1AoPo1XBYdO',
#     'name': '960-180-200-180-200-200_4.png',
#     'mimeType': 'image/png'},
#    '920-160-200-180-180-200_7.png': {'kind': 'drive#file',
#     'id': '1udEZvpFcY5nvJuTXDE-kapbvXVTEMg5d',
#     'name': '920-160-200-180-180-200_7.png',
#     'mimeType': 'image/png'},
#    '960-160-200-200-200-200_2.png': {'kind': 'drive#file',
#     'id': '1khrxquRViiE82SRtH3MG66WpSThe1GMH',
#     'name': '960-160-200-200-200-200_2.png',
#     'mimeType': 'image/png'},
#    '920-160-160-200-200-160_30.png': {'kind': 'drive#file',
#     'id': '1drjb5sa13OyjnWYFMmAahEIRt5toC7Gl',
#     'name': '920-160-160-200-200-160_30.png',
#     'mimeType': 'image/png'},
#    '900-160-200-160-200-180_22.png': {'kind': 'drive#file',
#     'id': '18bV7Hjp2nuHRabtGxD448jxG8HxYsY5i',
#     'name': '900-160-200-160-200-180_22.png',
#     'mimeType': 'image/png'},
#    '880-160-180-160-200-180_33.png': {'kind': 'drive#file',
#     'id': '1EnqannVQr4Jr55BjTGPl420hyAnJiT28',
#     'name': '880-160-180-160-200-180_33.png',
#     'mimeType': 'image/png'},
#    '960-160-200-200-200-200_301.png': {'kind': 'drive#file',
#     'id': '1695rX1DU6njLFHYhaU9Q1x55Zy4fm-PG',
#     'name': '960-160-200-200-200-200_301.png',
#     'mimeType': 'image/png'},
#    '860-160-180-160-180-180_4.png': {'kind': 'drive#file',
#     'id': '19hj3rw7T_P3UQ1Dv9eztaZdhP-2n9ccc',
#     'name': '860-160-180-160-180-180_4.png',
#     'mimeType': 'image/png'},
#    '900-160-200-180-160-200_52.png': {'kind': 'drive#file',
#     'id': '1fMvwbHcnMYoBvbnmcCs3exAS2tkhpFRV',
#     'name': '900-160-200-180-160-200_52.png',
#     'mimeType': 'image/png'},
#    '920-160-200-200-180-180_39.png': {'kind': 'drive#file',
#     'id': '1QAZ2hmSZS7cxEMIWxJda7tpuJddUWST9',
#     'name': '920-160-200-200-180-180_39.png',
#     'mimeType': 'image/png'},
#    '940-180-200-200-180-180_300.png': {'kind': 'drive#file',
#     'id': '1dBD_sURnW8quaMWJ1SYCXJ-bHbdjKSIQ',
#     'name': '940-180-200-200-180-180_300.png',
#     'mimeType': 'image/png'},
#    '960-160-200-200-200-200_1.png': {'kind': 'drive#file',
#     'id': '1JmZBNPGhLnucc7WRu81vdPdcHxx5Jwe8',
#     'name': '960-160-200-200-200-200_1.png',
#     'mimeType': 'image/png'},
#    '900-160-200-200-160-180_9.png': {'kind': 'drive#file',
#     'id': '19NJl8kcUc6HEGfpTec9QWr3vwdJmurcv',
#     'name': '900-160-200-200-160-180_9.png',
#     'mimeType': 'image/png'},
#    '880-160-200-160-200-160_48.png': {'kind': 'drive#file',
#     'id': '1NzpQScERaeTPhclNIa7lUmTIgpHXF2XC',
#     'name': '880-160-200-160-200-160_48.png',
#     'mimeType': 'image/png'},
#    '800-160-160-160-160-160_53.png': {'kind': 'drive#file',
#     'id': '1VGNd3gCsZwKRckYSYU2i6y1ZntCARo6O',
#     'name': '800-160-160-160-160-160_53.png',
#     'mimeType': 'image/png'},
#    '900-160-160-180-200-200_51.png': {'kind': 'drive#file',
#     'id': '1jyKdt5FyBA1vJtSdyr9GoZM-CWy-Kcqk',
#     'name': '900-160-160-180-200-200_51.png',
#     'mimeType': 'image/png'},
#    '920-200-200-180-140-200_32.png': {'kind': 'drive#file',
#     'id': '13ZaqGkZc8_CXor3Mf6FqeL6d6Enz0SVL',
#     'name': '920-200-200-180-140-200_32.png',
#     'mimeType': 'image/png'},
#    '800-160-180-140-160-160_15.png': {'kind': 'drive#file',
#     'id': '1tiMySLq2qyp4AcyO6v9_ZOPaIR8GOSBY',
#     'name': '800-160-180-140-160-160_15.png',
#     'mimeType': 'image/png'}},
#   '2018.1': {'920_44.png': {'kind': 'drive#file',
#     'id': '1AyoH4ZogqtuI64BSZ6HCaRqRE2iePT_V',
#     'name': '920_44.png',
#     'mimeType': 'image/png'}},
#   '2016': {'.DS_Store': {'kind': 'drive#file',
#     'id': '1zWCYUY17P31_Vz_8nCkZHSjMg67Fsob0',
#     'name': '.DS_Store',
#     'mimeType': 'application/octet-stream'},
#    '820-160-160-160-180-160_54.png': {'kind': 'drive#file',
#     'id': '1z8-2IDtPjCJx6PFc0_y0iMQczx5N33dN',
#     'name': '820-160-160-160-180-160_54.png',
#     'mimeType': 'image/png'}},
#   '2018': {'940-180-200-180-180-200_26.png': {'kind': 'drive#file',
#     'id': '1TUqOsxw6tigBab-UlxT1BanTA-54saq_',
#     'name': '940-180-200-180-180-200_26.png',
#     'mimeType': 'image/png'},
#    '.DS_Store': {'kind': 'drive#file',
#     'id': '1Ju13_tvl-sjmNzJNkKimYwWBbBTWMIOd',
#     'name': '.DS_Store',
#     'mimeType': 'application/octet-stream'},
#    '960-180-200-180-200-200_31.png': {'kind': 'drive#file',
#     'id': '1oV7r3jxg7-KqX7wAF5YyD_hL24v01Rzu',
#     'name': '960-180-200-180-200-200_31.png',
#     'mimeType': 'image/png'},
#    '980-180-200-200-200-200_2.png': {'kind': 'drive#file',
#     'id': '1XOuEHypoouzLPy13SGpymM8lKNZ7UTtg',
#     'name': '980-180-200-200-200-200_2.png',
#     'mimeType': 'image/png'}},
#   '2019.1': {'900_308.png': {'kind': 'drive#file',
#     'id': '1GUdTBNyZTIyAgmiOTpcE6xKTq1GK-raM',
#     'name': '900_308.png',
#     'mimeType': 'image/png'},
#    '920_306.png': {'kind': 'drive#file',
#     'id': '1u4VbtzWHjquOpwf4o9_58Qwg3MOxGTEy',
#     'name': '920_306.png',
#     'mimeType': 'image/png'},
#    '900_2.png': {'kind': 'drive#file',
#     'id': '1ZxKUmN1AfPhZiaBPQDJ8cQMP8CXp8lBT',
#     'name': '900_2.png',
#     'mimeType': 'image/png'}},
#   '2019': {'900-180-200-160-200-160_307.png': {'kind': 'drive#file',
#     'id': '13Zcdz01WOZ_uLZSxNmXP3XHB01S_Qmwc',
#     'name': '900-180-200-160-200-160_307.png',
#     'mimeType': 'image/png'},
#    '960-200-200-160-200-200_8.png': {'kind': 'drive#file',
#     'id': '1Da1bcLcGar0Ev0A6V_v7kn1awDTG2YhP',
#     'name': '960-200-200-160-200-200_8.png',
#     'mimeType': 'image/png'},
#    '720-120-180-140-120-160_14.png': {'kind': 'drive#file',
#     'id': '1H6Hx-S4bftdwpge_ExUhDTNQ3y9jizXI',
#     'name': '720-120-180-140-120-160_14.png',
#     'mimeType': 'image/png'},
#    '740-140-120-160-120-200_23.png': {'kind': 'drive#file',
#     'id': '1AA1bHrmhjcYFS4WFnc9CZAASE83e70wR',
#     'name': '740-140-120-160-120-200_23.png',
#     'mimeType': 'image/png'},
#    '920-160-200-160-200-200_6.png': {'kind': 'drive#file',
#     'id': '1eCshG2MBp5VqaLw3vWwkPiJfK3crTSS0',
#     'name': '920-160-200-160-200-200_6.png',
#     'mimeType': 'image/png'},
#    '960-200-200-180-180-200_27.png': {'kind': 'drive#file',
#     'id': '17KMGL7ls3BrQhWHL_WaCZaggpGGwFF2m',
#     'name': '960-200-200-180-180-200_27.png',
#     'mimeType': 'image/png'},
#    '940-160-200-200-180-200_47.png': {'kind': 'drive#file',
#     'id': '1Z_xHAFyoak8FvFIwO8kzlpPHh_4YB9rw',
#     'name': '940-160-200-200-180-200_47.png',
#     'mimeType': 'image/png'},
#    '940-160-200-180-200-200_43.png': {'kind': 'drive#file',
#     'id': '1Am90n_wxpUmEWeF7T_Grq5RLZ4xy69J4',
#     'name': '940-160-200-180-200-200_43.png',
#     'mimeType': 'image/png'},
#    '920-160-200-200-200-160_9.png': {'kind': 'drive#file',
#     'id': '1y8mxfhSemOXQv1wFrxdjBd8TdLKxl0uc',
#     'name': '920-160-200-200-200-160_9.png',
#     'mimeType': 'image/png'},
#    '940-160-200-200-180-180_0.png': {'kind': 'drive#file',
#     'id': '1ngXb0OROoxsQW4P98uXCdJAf1Oi7ncL3',
#     'name': '940-160-200-200-180-180_0.png',
#     'mimeType': 'image/png'},
#    '940-180-200-180-200-180_19.png': {'kind': 'drive#file',
#     'id': '18BDwbl_EvJlbbTlvgl9_zF2LXIabDOKW',
#     'name': '940-180-200-180-200-180_19.png',
#     'mimeType': 'image/png'},
#    '940-160-200-180-200-200_16.png': {'kind': 'drive#file',
#     'id': '13OSOO2IBB4dky4s875z6jDsRgUIkwk63',
#     'name': '940-160-200-180-200-200_16.png',
#     'mimeType': 'image/png'},
#    '960-160-200-200-200-200_46.png': {'kind': 'drive#file',
#     'id': '1NCbG_SUT2SV86VntpTO_1B_WKbPdsPpH',
#     'name': '960-160-200-200-200-200_46.png',
#     'mimeType': 'image/png'},
#    '980-180-200-200-200-200_34.png': {'kind': 'drive#file',
#     'id': '1el9Nb8Yt5ygVac16SSf4A0OsTN2I_-I1',
#     'name': '980-180-200-200-200-200_34.png',
#     'mimeType': 'image/png'},
#    '900-160-200-160-200-180_7.png': {'kind': 'drive#file',
#     'id': '1tpzaJqmRbfnPtEAl0I4JX_7g_hNfEWrq',
#     'name': '900-160-200-160-200-180_7.png',
#     'mimeType': 'image/png'},
#    '800-160-160-140-180-160_13.png': {'kind': 'drive#file',
#     'id': '1hBvICl7i939256JfvB2Clg8aEENhfaqs',
#     'name': '800-160-160-140-180-160_13.png',
#     'mimeType': 'image/png'},
#    '980-180-200-200-200-200_56.png': {'kind': 'drive#file',
#     'id': '1jWNDkcKZ5QOStWxeROJJxqKIaVu-qvnt',
#     'name': '980-180-200-200-200-200_56.png',
#     'mimeType': 'image/png'},
#    '940-180-200-180-200-180_36.png': {'kind': 'drive#file',
#     'id': '1J-FZhwf3_UOwYuOehm8bOoB0MjlJSqNo',
#     'name': '940-180-200-180-200-180_36.png',
#     'mimeType': 'image/png'},
#    '940-160-200-180-200-200_49.png': {'kind': 'drive#file',
#     'id': '1invFnWH6rj6WTFKUhQYlsEuddMQkncoh',
#     'name': '940-160-200-180-200-200_49.png',
#     'mimeType': 'image/png'},
#    '980-180-200-200-200-200_25.png': {'kind': 'drive#file',
#     'id': '1Iwob1OpjlbZVsblB0GGMazIFrru9A1sT',
#     'name': '980-180-200-200-200-200_25.png',
#     'mimeType': 'image/png'},
#    '940-160-200-200-180-200_5.png': {'kind': 'drive#file',
#     'id': '13TKS6EyB9vKF3W74NRfsz1-ZlaoKU97h',
#     'name': '940-160-200-200-180-200_5.png',
#     'mimeType': 'image/png'},
#    '940-160-200-180-200-200_50.png': {'kind': 'drive#file',
#     'id': '1feDXmMHzozgu_OjIiVBU2xRfWo9be9aJ',
#     'name': '940-160-200-180-200-200_50.png',
#     'mimeType': 'image/png'},
#    '980-200-200-200-200-180_1.png': {'kind': 'drive#file',
#     'id': '1MBGH6jmImo5DsCa2tjV5YJc50bWoAGUU',
#     'name': '980-200-200-200-200-180_1.png',
#     'mimeType': 'image/png'},
#    '980-180-200-200-200-200_12.png': {'kind': 'drive#file',
#     'id': '116AOmvG3rzRUmikXYOyBJTjvWIpzDSRM',
#     'name': '980-180-200-200-200-200_12.png',
#     'mimeType': 'image/png'},
#    '920-160-200-200-200-160_0.png': {'kind': 'drive#file',
#     'id': '1qO3Uw-rPMc3gHLc18zHGP-desu0AN29E',
#     'name': '920-160-200-200-200-160_0.png',
#     'mimeType': 'image/png'},
#    '800-140-200-160-140-160_18.png': {'kind': 'drive#file',
#     'id': '1598BiaT1_3bz2vAQ1DtshQc9LEVWcQre',
#     'name': '800-140-200-160-140-160_18.png',
#     'mimeType': 'image/png'},
#    '940-160-200-160-200-200_29.png': {'kind': 'drive#file',
#     'id': '1n_GEdglG_45sdQLcSmmEtDeAA5tIzplS',
#     'name': '940-160-200-160-200-200_29.png',
#     'mimeType': 'image/png'},
#    '960-180-200-200-200-180_40.png': {'kind': 'drive#file',
#     'id': '13foxHdGoYySdyn6UPvVRCGhDJ6q1RUlU',
#     'name': '960-180-200-200-200-180_40.png',
#     'mimeType': 'image/png'},
#    '920-180-200-180-180-180_6.png': {'kind': 'drive#file',
#     'id': '1kIpF0GaEZKRhKQHf7si0k-Elt1ID5vPS',
#     'name': '920-180-200-180-180-180_6.png',
#     'mimeType': 'image/png'},
#    '960-160-200-200-200-200_10.png': {'kind': 'drive#file',
#     'id': '1FjlpmOtfO9KeiwnlTCDqtgxnaOxDCKxL',
#     'name': '960-160-200-200-200-200_10.png',
#     'mimeType': 'image/png'},
#    '940-160-180-200-200-200_305.png': {'kind': 'drive#file',
#     'id': '1d7yiTVKeF_gpSA_9mJsAAWF2q6rv6qKo',
#     'name': '940-160-180-200-200-200_305.png',
#     'mimeType': 'image/png'},
#    '920-160-200-180-180-200_1.png': {'kind': 'drive#file',
#     'id': '1oyQsuQIBGGUN5EJBhEX7_bzSJI0cEHTy',
#     'name': '920-160-200-180-180-200_1.png',
#     'mimeType': 'image/png'},
#    '920-180-200-180-200-160_3.png': {'kind': 'drive#file',
#     'id': '1SkPYSw_Xoq0Wui-XLLk7nm_Mnc0IJ7ra',
#     'name': '920-180-200-180-200-160_3.png',
#     'mimeType': 'image/png'},
#    '920-180-180-180-180-200_5.png': {'kind': 'drive#file',
#     'id': '1S6AINcBoapgVZPDIWTTwwfrsIzAUjgmR',
#     'name': '920-180-180-180-180-200_5.png',
#     'mimeType': 'image/png'},
#    '880-160-180-200-180-160_41.png': {'kind': 'drive#file',
#     'id': '154-xrk5XA5FjtvgJxAkCG-2dLWZLwp0s',
#     'name': '880-160-180-200-180-160_41.png',
#     'mimeType': 'image/png'},
#    '900-160-200-200-160-180_21.png': {'kind': 'drive#file',
#     'id': '1JCZrzP4ZAAMkmV6usdnrL8ppbS8qePQV',
#     'name': '900-160-200-200-160-180_21.png',
#     'mimeType': 'image/png'},
#    '840-140-180-160-180-180_38.png': {'kind': 'drive#file',
#     'id': '1YrWMfyafkwtj7RWuXCaAKaqsFjU3Oofu',
#     'name': '840-140-180-160-180-180_38.png',
#     'mimeType': 'image/png'},
#    '.DS_Store': {'kind': 'drive#file',
#     'id': '1_7oAL-ksbFaAI3yfdi9pzOfd9wkwtDjq',
#     'name': '.DS_Store',
#     'mimeType': 'application/octet-stream'}},
#   '2020.1': {'red-enem-short.py': {'kind': 'drive#file',
#     'id': '1DqIw5DpsGedkdsiPfdDMk2EBRn59O-Z_',
#     'name': 'red-enem-short.py',
#     'mimeType': 'text/x-python'},
#    '960_2.png': {'kind': 'drive#file',
#     'id': '1KMUjWmAvDhZ1KptJ-RQxb6Ib7wPBjJd8',
#     'name': '960_2.png',
#     'mimeType': 'image/png'}}}}

# %%
print(file_items.keys())
# Out:
# dict_keys(['Fuvest', 'Enem'])

# %%
enem_tree = file_items['Enem']
fuvest_tree = file_items['Fuvest']

ENEM_COLS = [
    'ano',
    'nota',
    'c1',
    'c2',
    'c3',
    'c4',
    'c5',
    'drive_id',
    'url',
]

FUVEST_COLS = [
    'ano',
    'nota',
    'drive_id',
    'url',
]

# %%
DRIVE_VIEW_BASE_URL = 'https://drive.google.com/file/d/{}/view'

# %%
def parse_enem_essays(filetree, base_view_url, columns):
    data = []
    for raw_year, file_dict in filetree.items():
        year = raw_year.split('.')[0]
        essay_dict = {filename: item for filename, item in file_dict.items() if is_essay_file(item)}
        for filename, drive_item in essay_dict.items():
            marks = filename.split('_')[0].split('-')
            if len(marks) > 1:
                final_marks = marks
            else:
                final_marks = [marks[0], None, None, None, None, None]
            file_view_url = base_view_url.format(drive_item['id'])
            data.append([year, *final_marks, drive_item['id'], file_view_url])
    
    return pd.DataFrame(data=data, columns=columns).convert_dtypes()

# %%
enem_parsed = parse_enem_essays(enem_tree, DRIVE_VIEW_BASE_URL, ENEM_COLS)
enem_parsed
# Out:
#      ano nota    c1    c2    c3    c4    c5  \
# 0   2020  920   160   200   160   200   200
# 1   2020  960   180   200   180   200   200
# 2   2020  900   180   180   200   180   160
# 3   2020  960   180   200   180   200   200
# 4   2020  860   160   200   160   180   160
# ..   ...  ...   ...   ...   ...   ...   ...
# 72  2019  920   180   180   180   180   200
# 73  2019  880   160   180   200   180   160
# 74  2019  900   160   200   200   160   180
# 75  2019  840   140   180   160   180   180
# 76  2020  960  <NA>  <NA>  <NA>  <NA>  <NA>
#
#                              drive_id  \
# 0   1CA5BuMVUlOGedcrzcyfSHRhuU2ksJCOk
# 1   1ozFxlkdFl0nkXdklVV7I75uLX0G_R_qx
# 2   1nxDup_a1LX1Tm61isRt8eVBNaNCDfMiR
# 3   1Y65pUXqvHbMKadsZCNdNWTO2YXeDrdpx
# 4   1E7PcM9kXvfiJ_EEZBLE5_ovssz-6KEZ8
# ..                                ...
# 72  1S6AINcBoapgVZPDIWTTwwfrsIzAUjgmR
# 73  154-xrk5XA5FjtvgJxAkCG-2dLWZLwp0s
# 74  1JCZrzP4ZAAMkmV6usdnrL8ppbS8qePQV
# 75  1YrWMfyafkwtj7RWuXCaAKaqsFjU3Oofu
# 76  1KMUjWmAvDhZ1KptJ-RQxb6Ib7wPBjJd8
#
#                                                   url
# 0   https://drive.google.com/file/d/1CA5BuMVUlOGed...
# 1   https://drive.google.com/file/d/1ozFxlkdFl0nkX...
# 2   https://drive.google.com/file/d/1nxDup_a1LX1Tm...
# 3   https://drive.google.com/file/d/1Y65pUXqvHbMKa...
# 4   https://drive.google.com/file/d/1E7PcM9kXvfiJ_...
# ..                                                ...
# 72  https://drive.google.com/file/d/1S6AINcBoapgVZ...
# 73  https://drive.google.com/file/d/154-xrk5XA5Fjt...
# 74  https://drive.google.com/file/d/1JCZrzP4ZAAMkm...
# 75  https://drive.google.com/file/d/1YrWMfyafkwtj7...
# 76  https://drive.google.com/file/d/1KMUjWmAvDhZ1K...
#
# [77 rows x 9 columns]

# %%
def parse_fuvest_essays(filetree, base_view_url, columns):
    data = []
    for year, file_dict in filetree.items():
        if year != '50.pdf': # One file was misplaced
            essay_dict = {filename: item for filename, item in file_dict.items() if is_essay_file(item)}
            for filename, drive_item in essay_dict.items():
                mark = filename.split('_')[0].split('-')[0].replace(',', '.')
                file_view_url = base_view_url.format(drive_item['id'])
                data.append([year, mark, drive_item['id'], file_view_url])
    
    return pd.DataFrame(data=data, columns=columns).convert_dtypes()

# %%
fuvest_parsed = parse_fuvest_essays(fuvest_tree, DRIVE_VIEW_BASE_URL, FUVEST_COLS)
fuvest_parsed
# Out:
#       ano  nota                           drive_id  \
# 0    2018  36.5  1ThLLNWnUHgGq55ElFVUFVysSem8o83HY
# 1    2018   33   1J6c8CNdx6Yy1ye0gK8DLo1Oo3yUL3DLK
# 2    2020  38.5  1pJ5_z-00dpX4mbsPSzUsLX4pKFuWE434
# 3    2020  42.0  1p2WISpPRTiRxxb8uzyyf3Qbkd2OgkaiS
# 4    2020  43.0  1y0lhK2DInBrNr29fNcmR1jUo3SZKhjZU
# ..    ...   ...                                ...
# 127  2019  40.0  1QxwnC7lRJNdWG8VHcgGIFiwEgvumglDs
# 128  2019  38.0  1W7ThT5NwhBw0S7ZKrt5Q0r3P0yKAkc2B
# 129  2019  47.0  1B9TUmIT_23DROVS7LDyaxKV7nGgY4g7W
# 130  2019  35.0  1_CvW_Kz4x0ROdP0DQcSYh_YGtjfRaA9F
# 131  2019  27.0  1B3Gf7sUZh9SOANn673oAqeTX5T9-tQ7U
#
#                                                    url
# 0    https://drive.google.com/file/d/1ThLLNWnUHgGq5...
# 1    https://drive.google.com/file/d/1J6c8CNdx6Yy1y...
# 2    https://drive.google.com/file/d/1pJ5_z-00dpX4m...
# 3    https://drive.google.com/file/d/1p2WISpPRTiRxx...
# 4    https://drive.google.com/file/d/1y0lhK2DInBrNr...
# ..                                                 ...
# 127  https://drive.google.com/file/d/1QxwnC7lRJNdWG...
# 128  https://drive.google.com/file/d/1W7ThT5NwhBw0S...
# 129  https://drive.google.com/file/d/1B9TUmIT_23DRO...
# 130  https://drive.google.com/file/d/1_CvW_Kz4x0ROd...
# 131  https://drive.google.com/file/d/1B3Gf7sUZh9SOA...
#
# [132 rows x 4 columns]

# %%
enem_parsed.to_csv('../../data/4_final/redacoes/enem/2020.csv', index=None)
fuvest_parsed.to_csv('../../data/4_final/redacoes/fuvest/2020.csv', index=None)

# %% [markdown]
# ## Experimentation

# %%
def drive_api_key():
    """Shows basic usage of the Drive v3 API.
    Prints the names and ids of the first 10 files the user has access to.
    """
    try:
        service = build('drive', 'v3',
                        developerKey='AIzaSyBU7WIsMv5LvRD3xt8ZnV5fqfMY40iEHS8')

        # Call the Drive v3 API
        folder_id = '1NxxkhOfH4eB0v6E0leGtG5hHo2amYKmG'
        query = f"'{folder_id}' in parents"
        results = service.files().list(q=query).execute()
        items = results.get('files')

        if not items:
            print('No files found.')
            return
        print('Files:')
        print(type(items))
        for item in items:
            print(u'{0} ({1})'.format(item['name'], item['id']))
            print(item['mimeType'])
            if item['mimeType'] == 'application/vnd.google-apps.folder':
                new_result = service.files().list(q=f"'{item['id']}' in parents").execute()
                new_items = new_result.get('files')
                for new_item in new_items:
                    print(u'{0} ({1})'.format(new_item['name'], new_item['id']))
                    print(new_item['mimeType'])

    except HttpError as error:
        # TODO(developer) - Handle errors from drive API.
        print(f'An error occurred:\n\n{error}')

# %%
drive_api_key()
# Out:
# Files:
# <class 'list'>
# Fuvest (14GBnussetkKp_PUjjyXOM1Z9G4-KEyCE)
# application/vnd.google-apps.folder
# 50.pdf (1SziOtl8xeATY3cfA2VXf9NRLK0-b3ENg)
# application/pdf
# 2018 (1INWnsAKSZH-AcRB9gHCyRbxBbozvUIs1)
# application/vnd.google-apps.folder
# 2020 (1Dxc8x7ogmfFT4RxMOcGqhb0DCgDQa1Ei)
# application/vnd.google-apps.folder
# 2019 (1Bf0BQ1OCwiZFYJVAE1ua-8CPVaOrcpx_)
# application/vnd.google-apps.folder
# Enem (1pPdte9umchy4HdEyFf7IbLHeTNerWXP2)
# application/vnd.google-apps.folder
# 2020 (1HeGrZN09iPYrhmn-ZOcCWhMzuxuA2pPO)
# application/vnd.google-apps.folder
# 2018.1 (1ypayvnq4pjEHObVmZNuVqKwg51MsnBiV)
# application/vnd.google-apps.folder
# 2016 (1IiDtYdqpX5hoB_zMUU47A-NTH1X-IicD)
# application/vnd.google-apps.folder
# 2018 (1drPlWbQV4MsCXGVIRKmFxsnSSULJrW3X)
# application/vnd.google-apps.folder
# 2019.1 (1wRcsWQwgoJNWJNEZ0MAi1GKI7VHtVFqo)
# application/vnd.google-apps.folder
# 2019 (1rV403v8H6lyf6XAQvpZcPZOOXfo1k2mC)
# application/vnd.google-apps.folder
# 2020.1 (1rirpbY1EVdfHeh0bms2uClf6hPJX7z2Z)
# application/vnd.google-apps.folder

# %%
def drive_service():
    SCOPES = ['https://www.googleapis.com/auth/drive']
    SERVICE_ACCOUNT_FILE = 'service.json'
    credentials = service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)

    try:
        service = build('drive', 'v3', credentials=credentials)

        # Call the Drive v3 API

        # file_path = '/home/tomaz/Downloads/Apostila---Produtividade-Na-Pratica-Online.pdf'
        # file_metadata = {'name': 'pdf_exemplo.pdf'}
        # media = MediaFileUpload(file_path, mimetype='application/pdf')
        # file = service.files().create(body=file_metadata,
        #                                     media_body=media,
        #                                     fields='id').execute()
        #
        # result = service.about().get(fields='storageQuota').execute()
        # print(result)

        # results = service.files().list(
        #     pageSize=10).execute()
        # items = results.get('files', [])
        #
        # if not items:
        #     print('No files found.')
        #     return
        # print('Files:')
        # for item in items:
        #     print(u'{0} ({1})'.format(item['name'], item['id']))

        # file_id = '1-H2egFbxXfJPM2EifumTIJMwQH9Q5DNU'
        # permissions = {
        #     'type': 'anyone',
        #     'role': 'reader',
        # }
        # service.permissions().create(
        #     fileId=file_id,
        #     body=permissions,
        #     fields='id',
        # ).execute()

        from googleapiclient.http import MediaIoBaseDownload

        file_id = '1-H2egFbxXfJPM2EifumTIJMwQH9Q5DNU'
        request = service.files().get_media(fileId=file_id)
        with open('example.pdf', 'wb') as output:
            downloader = MediaIoBaseDownload(output, request)
            done = False
            while done is False:
                status, done = downloader.next_chunk()
                print(f"Download {int(status.progress() * 100)}")

    except HttpError as error:
        # TODO(developer) - Handle errors from drive API.
        print(f'An error occurred: {error}')

# %%
drive_service()
# Out:
# Download 100
