# %% [markdown]
# ## Setup

# %%
from os import listdir, makedirs
from os.path import join, isdir, splitext
from unidecode import unidecode

from jinja2 import Environment, FileSystemLoader, select_autoescape
import pandas as pd

# %%
TEMPLATES_DIR = '../../templates'
CONTENT_DIR = '../../data/4_content'
GRADES_RESULT_DIR = '../../website/notas'

ID_TABLE_PATH = '../../data/3_manually_processed/vagas/2022.csv'
ESSAYS_DIR = '../../data/3_manually_processed/redacoes'
ESSAYS_RESULT_DIR = '../../website/redacoes'

# %% [markdown]
# ## Support functions

# %%
def clean_string(string):
    alphanumerical_chars = [char for char in string if char.isalnum()]
    return unidecode("".join(alphanumerical_chars))

# %%
def get_course_name(course_id, id_df):
    return id_df[id_df.id == course_id].curso.iloc[0]

# %%
def get_course_institute(course_id, id_df):
    return id_df[id_df.id == course_id].unidade.iloc[0]

# %%
def get_course_name_institute(course_id, id_df):
    name = get_course_name(course_id, id_df)
    institure = get_course_institute(course_id, id_df)
    return name, institure

# %%
def create_render_save_path(result_dir=None, course_id=None,
                            new_dir=None, filename=None,
                            id_df=None):
    save_dir = ''
    if result_dir is not None and course_id is not None:
        save_dir = join(result_dir, str(course_id))
    if new_dir is not None:
        save_dir = join(save_dir, new_dir)
        makedirs(save_dir, exist_ok=True)
    if filename is None and id_df is not None:
        filename = get_course_name(course_id, id_df)
    clean_filename = clean_string(filename)

    return join(save_dir, clean_filename+'.html')

# %%
def save_website(website, path):
    with open(path, mode='w') as f:
        f.write(website)

# %% [markdown]
# ## Rendering

# %%
JINJA_ENV = Environment(
    loader=FileSystemLoader(TEMPLATES_DIR),
    autoescape=select_autoescape())

# %% [markdown]
# ### Grades

# %%
ID_DF = pd.read_csv(ID_TABLE_PATH).convert_dtypes()
print(ID_DF.dtypes)
ID_DF
# Out:
# id              Int64
# unidade        string
# area           string
# curso          string
# fuvest_ac       Int64
# fuvest_ep       Int64
# fuvest_ppi      Int64
# fuvest          Int64
# enem_ac         Int64
# enem_ep_l1      Int64
# enem_ep_l3      Int64
# enem_ep         Int64
# enem_ppi_l2     Int64
# enem_ppi_l4     Int64
# enem_ppi        Int64
# enem            Int64
# dtype: object
#       id unidade area                                              curso  \
# 0      0    EACH    E              Bacharelado em Sistemas de Informação
# 1      1    EACH    E              Bacharelado em Sistemas de Informação
# 2      2    EACH    E               Licenciatura em Ciências da Natureza
# 3      3    EACH    B             Bacharelado em Educação Física e Saúde
# 4      4    EACH    B                       Bacharelado em Biotecnologia
# ..   ...     ...  ...                                                ...
# 172  171      IQ    E  Química – Bacharelado e Licenciatura – Integra...
# 173  172      IQ    E  Química – Bacharelado e Licenciatura – Noturno...
# 174  173    IQSC    E  Química Bacharelado (Hab. Fundamental e Hab. T...
# 175  174     IRI    H             Bacharelado em Relações Internacionais
# 176  175     IRI    H             Bacharelado em Relações Internacionais
#
#      fuvest_ac  fuvest_ep  fuvest_ppi  fuvest  enem_ac  enem_ep_l1  \
# 0           28         10           4      42        2           0
# 1           56         21           7      84        4           0
# 2           30          9           3      42        0           0
# 3           20         14           8      42       10           4
# 4           30         11           1      42        0           0
# ..         ...        ...         ...     ...      ...         ...
# 172         22         12           8      42        8           2
# 173         22         12           8      42        8           2
# 174         24         12           6      42        6           3
# 175         14          5           2      21        1           3
# 176         14          5           2      21        1           3
#
#      enem_ep_l3  enem_ep  enem_ppi_l2  enem_ppi_l4  enem_ppi  enem
# 0             8        8            0            8         8    18
# 1            16       16            0           16        16    36
# 2             9        9            0            9         9    18
# 3             0        4            4            0         4    18
# 4             7        7            0           11        11    18
# ..          ...      ...          ...          ...       ...   ...
# 172           4        6            2            2         4    18
# 173           4        6            2            2         4    18
# 174           3        6            3            3         6    18
# 175           1        4            3            1         4     9
# 176           1        4            3            1         4     9
#
# [177 rows x 16 columns]

# %%
get_course_name(0, ID_DF)
# Out:
# 'Bacharelado em Sistemas de Informação'

# %% [markdown]
# #### Courses

# %%
def read_course_templates(jinja_env,
        fuvest_filename='notas.html.jinja',
        ):
    # TODO enem_course_template = jinja_env.get_template('curso_enem.html.jinja')
    return (
        jinja_env.get_template(fuvest_filename),
    )

# %%
for course_id_str in listdir(CONTENT_DIR):
    if isdir(join(CONTENT_DIR, course_id_str)):
        course_id = int(course_id_str)
        course_name = get_course_name(course_id, ID_DF)
        print(course_name)
# Out:
# Pedagogia
# Farmácia
# Bach. Com. Social: Editoração
# Ciências dos Alimentos - Bach.
# Psicologia - Bach. e Psicólogo
# Licenciatura em Educomunicação
# Física – Bacharelado
# Bacharelado em Ciências Atuariais
# Bacharelado em Finanças e Negócios
# Engenharia Elétrica (Ênfase em Eletrônica)
# Engenharia de Materiais
# Odontologia
# Física – Bacharelado
# Engenharia Mecatrônica
# Bacharelado em Relações Públicas
# Arquitetura e Urbanismo
# Medicina
# Direito
# Engenharia Agronômica
# Medicina Veterinária
# Direito
# Engenharia Aeronáutica
# Bacharelado em Ciências Físicas e Biomoleculares -Ênfase Tecnológica
# Fonoaudiologia
# História - Bach./Lic.
# Bacharelado em Ciências Econômicas
# Engenharia Elétrica (Ênfase em Sistemas de Energia e Automação)
# Bacharelado em Física Médica
# Engenharia Florestal
# Direito
# Letras – Bach./Lic.
# Matemática - Licenciatura
# Engenharia Naval
# Filosofia - Bach./Lic.
# Nutrição
# Bacharelado em Ciências Econômicas
# Matemática Aplicada - Bacharelado
# Bacharelado em Biotecnologia
# Arquitetura e Urbanismo
# Bacharelado em Ciências de Computação
# Bacharelado em Administração
# Química Bacharelado (Hab. Fundamental e Hab. Tecnológica com ênfases em Alimentos; Ambiental; Gestão de Qualidade; Materiais)
# Geologia
# Engenharia Química
# Artes Visuais - Bach. e Lic.
# Bacharelado em Ciência da Computação
# Bacharelado em Têxtil e Moda
# Engenharia de Produção
# Engenharia de Computação
# Engenharia de Materiais; Engenharia Metalúrgica; Engenharia Nuclear
# Ciências Biológicas - Bach. e Lic.
# Bach. Com. Social: Publicidade e Propaganda
# Engenharia Elétrica (Ênfases: Automação e
# Controle, Energia e Automação Elétricas,
# Eletrônica e Sistemas Computacionais,
# Telecomunicações)
# Matemática - Bach. e Licenciatura
# Bacharelado em Ciências Econômicas
# Zootecnia
# Fisioterapia
# Turismo
# Engenharia de Minas
# Matemática Aplic. e Comput. Científica
# Gestão Ambiental - Bacharelado
# Fisioterapia
# Marketing
# Bacharelado em Astronomia
# Ciências Econômicas - Bacharelado
# Bacharelado em Relações Internacionais
# Geografia - Bach./Lic.
# Engenharia Bioquímica
# Química - Bacharelado – Habilitações:
# Química Bacharelado; Química Forense;
# Química Tecnológica, Biotecnologia e
# Agroindústria
# Engenharia Mecânica
# Psicologia - Bach./Lic. e Psicólogo
# Música - Bacharelado e  Educação Artística
# Engenharia de Materiais e Manufatura
# Licenciatura em Ciências da Natureza
# Bacharelado em Oceanografia
# Bacharelado em Física Computacional
# Química – Bacharelado e Licenciatura – Noturno (Bach. – Ênfase em Química)
# Engenharia Civil
# Medicina Veterinária
# Engenharia Civil
# Terapia Ocupacional
# Química – Bacharelado e Licenciatura – Integral (Bach. – Ênfases: Tecnológica; Biotecnologia; Bioquímica e Biologia Molecular)
# Informática Biomédica
# Bacharelado em Jornalismo
# Engenharia Química (quadrimestral)
# Design
# Bacharelado em Sistemas de Informação
# Engenharia Mecânica
# Ciências Sociais - Bach./Lic.
# Bacharelado em Administração
# Bacharelado em Ciência da Computação
# Engenharia Química
# Estatística - Bacharelado
# Matemática - Bacharelado
# Bacharelado em Gestão Ambiental
# Curso Superior do Audiovisual
# Engenharia de Produção
# Curso de Graduação em Obstetrícia
# Gestão de Políticas Públicas
# Engenharia Mecatrônica
# Ciências Biológicas - Bach./Lic.
# Odontologia
# Biblioteconomia
# Ciências Contábeis - Bach.
# Enfermagem – Bach. e Lic.
# Engenharia de Petróleo
# Enfermagem - Bach. e Lic.
# Bacharelado em Sistemas de Informação
# Engenharia Ambiental
# Medicina
# Engenharia Ambiental
# Ciências Biológicas – Bacharelado e Licenciatura
# Bacharelado em Administração
# Bach. em Matemática Aplicada e Computacional
# Medicina
# Fonoaudiologia
# Bacharelado em Ciências Contábeis
# Engenharia de Computação
# Bacharelado em Ciências Biomédicas
# Pedagogia
# Bacharelado em Administração
# Artes Cênicas - Bach. e Lic.
# Farmácia
# Engenharia Física

# %%
for course_id_str in listdir(CONTENT_DIR):
    course_dir = join(CONTENT_DIR, course_id_str)
    if isdir(course_dir):
        course_id = int(course_id_str)
        course_name = get_course_name(course_id, ID_DF)
        for exam in listdir(course_dir):
            if exam == 'fuvest':
                fuvest_dir = join(course_dir, 'fuvest')
                print(f'{course_name} (ID {course_id_str})')
                print(fuvest_dir)
                print('\n')
            elif exam == 'enem':
                raise NotImplementedError("Only Fuvest grades can be parsed at the moment, not Enem's")
            else:
                raise NotImplementedError(f'Unknown exam type inside directory {course_dir}.')
# Out:
# Pedagogia (ID 91)
# ../../data/4_content/91/fuvest
#
#
# Farmácia (ID 76)
# ../../data/4_content/76/fuvest
#
#
# Bach. Com. Social: Editoração (ID 24)
# ../../data/4_content/24/fuvest
#
#
# Ciências dos Alimentos - Bach. (ID 67)
# ../../data/4_content/67/fuvest
#
#
# Psicologia - Bach. e Psicólogo (ID 97)
# ../../data/4_content/97/fuvest
#
#
# Licenciatura em Educomunicação (ID 30)
# ../../data/4_content/30/fuvest
#
#
# Física – Bacharelado (ID 156)
# ../../data/4_content/156/fuvest
#
#
# Bacharelado em Ciências Atuariais (ID 82)
# ../../data/4_content/82/fuvest
#
#
# Bacharelado em Finanças e Negócios (ID 90)
# ../../data/4_content/90/fuvest
#
#
# Engenharia Elétrica (Ênfase em Eletrônica) (ID 44)
# ../../data/4_content/44/fuvest
#
#
# Engenharia de Materiais (ID 36)
# ../../data/4_content/36/fuvest
#
#
# Odontologia (ID 130)
# ../../data/4_content/130/fuvest
#
#
# Física – Bacharelado (ID 152)
# ../../data/4_content/152/fuvest
#
#
# Engenharia Mecatrônica (ID 50)
# ../../data/4_content/50/fuvest
#
#
# Bacharelado em Relações Públicas (ID 27)
# ../../data/4_content/27/fuvest
#
#
# Arquitetura e Urbanismo (ID 72)
# ../../data/4_content/72/fuvest
#
#
# Medicina (ID 128)
# ../../data/4_content/128/fuvest
#
#
# Direito (ID 77)
# ../../data/4_content/77/fuvest
#
#
# Engenharia Agronômica (ID 65)
# ../../data/4_content/65/fuvest
#
#
# Medicina Veterinária (ID 124)
# ../../data/4_content/124/fuvest
#
#
# Direito (ID 79)
# ../../data/4_content/79/fuvest
#
#
# Engenharia Aeronáutica (ID 48)
# ../../data/4_content/48/fuvest
#
#
# Bacharelado em Ciências Físicas e Biomoleculares -Ênfase Tecnológica (ID 157)
# ../../data/4_content/157/fuvest
#
#
# Fonoaudiologia (ID 121)
# ../../data/4_content/121/fuvest
#
#
# História - Bach./Lic. (ID 109)
# ../../data/4_content/109/fuvest
#
#
# Bacharelado em Ciências Econômicas (ID 84)
# ../../data/4_content/84/fuvest
#
#
# Engenharia Elétrica (Ênfase em Sistemas de Energia e Automação) (ID 45)
# ../../data/4_content/45/fuvest
#
#
# Bacharelado em Física Médica (ID 177)
# ../../data/4_content/177/fuvest
#
#
# Engenharia Florestal (ID 66)
# ../../data/4_content/66/fuvest
#
#
# Direito (ID 78)
# ../../data/4_content/78/fuvest
#
#
# Letras – Bach./Lic. (ID 111)
# ../../data/4_content/111/fuvest
#
#
# Matemática - Licenciatura (ID 163)
# ../../data/4_content/163/fuvest
#
#
# Engenharia Naval (ID 63)
# ../../data/4_content/63/fuvest
#
#
# Filosofia - Bach./Lic. (ID 105)
# ../../data/4_content/105/fuvest
#
#
# Nutrição (ID 131)
# ../../data/4_content/131/fuvest
#
#
# Bacharelado em Ciências Econômicas (ID 85)
# ../../data/4_content/85/fuvest
#
#
# Matemática Aplicada - Bacharelado (ID 167)
# ../../data/4_content/167/fuvest
#
#
# Bacharelado em Biotecnologia (ID 4)
# ../../data/4_content/4/fuvest
#
#
# Arquitetura e Urbanismo (ID 139)
# ../../data/4_content/139/fuvest
#
#
# Bacharelado em Ciências de Computação (ID 146)
# ../../data/4_content/146/fuvest
#
#
# Bacharelado em Administração (ID 81)
# ../../data/4_content/81/fuvest
#
#
# Química Bacharelado (Hab. Fundamental e Hab. Tecnológica com ênfases em Alimentos; Ambiental; Gestão de Qualidade; Materiais) (ID 173)
# ../../data/4_content/173/fuvest
#
#
# Geologia (ID 160)
# ../../data/4_content/160/fuvest
#
#
# Engenharia Química (ID 38)
# ../../data/4_content/38/fuvest
#
#
# Artes Visuais - Bach. e Lic. (ID 17)
# ../../data/4_content/17/fuvest
#
#
# Bacharelado em Ciência da Computação (ID 101)
# ../../data/4_content/101/fuvest
#
#
# Bacharelado em Têxtil e Moda (ID 7)
# ../../data/4_content/7/fuvest
#
#
# Engenharia de Produção (ID 47)
# ../../data/4_content/47/fuvest
#
#
# Engenharia de Computação (ID 55)
# ../../data/4_content/55/fuvest
#
#
# Engenharia de Materiais; Engenharia Metalúrgica; Engenharia Nuclear  (ID 56)
# ../../data/4_content/56/fuvest
#
#
# Ciências Biológicas - Bach. e Lic. (ID 68)
# ../../data/4_content/68/fuvest
#
#
# Bach. Com. Social: Publicidade e Propaganda (ID 22)
# ../../data/4_content/22/fuvest
#
#
# Engenharia Elétrica (Ênfases: Automação e
# Controle, Energia e Automação Elétricas,
# Eletrônica e Sistemas Computacionais,
# Telecomunicações) (ID 60)
# ../../data/4_content/60/fuvest
#
#
# Matemática - Bach. e Licenciatura (ID 147)
# ../../data/4_content/147/fuvest
#
#
# Bacharelado em Ciências Econômicas (ID 89)
# ../../data/4_content/89/fuvest
#
#
# Zootecnia (ID 137)
# ../../data/4_content/137/fuvest
#
#
# Fisioterapia (ID 114)
# ../../data/4_content/114/fuvest
#
#
# Turismo (ID 21)
# ../../data/4_content/21/fuvest
#
#
# Engenharia de Minas (ID 57)
# ../../data/4_content/57/fuvest
#
#
# Matemática Aplic. e Comput. Científica (ID 148)
# ../../data/4_content/148/fuvest
#
#
# Gestão Ambiental - Bacharelado (ID 70)
# ../../data/4_content/70/fuvest
#
#
# Fisioterapia (ID 118)
# ../../data/4_content/118/fuvest
#
#
# Marketing (ID 14)
# ../../data/4_content/14/fuvest
#
#
# Bacharelado em Astronomia (ID 142)
# ../../data/4_content/142/fuvest
#
#
# Ciências Econômicas - Bacharelado (ID 69)
# ../../data/4_content/69/fuvest
#
#
# Bacharelado em Relações Internacionais (ID 174)
# ../../data/4_content/174/fuvest
#
#
# Geografia - Bach./Lic. (ID 107)
# ../../data/4_content/107/fuvest
#
#
# Engenharia Bioquímica (ID 37)
# ../../data/4_content/37/fuvest
#
#
# Química - Bacharelado – Habilitações:
# Química Bacharelado; Química Forense;
# Química Tecnológica, Biotecnologia e
# Agroindústria (ID 93)
# ../../data/4_content/93/fuvest
#
#
# Engenharia Mecânica (ID 46)
# ../../data/4_content/46/fuvest
#
#
# Psicologia - Bach./Lic. e Psicólogo (ID 170)
# ../../data/4_content/170/fuvest
#
#
# Música - Bacharelado e  Educação Artística (ID 102)
# ../../data/4_content/102/fuvest
#
#
# Engenharia de Materiais e Manufatura (ID 51)
# ../../data/4_content/51/fuvest
#
#
# Licenciatura em Ciências da Natureza (ID 2)
# ../../data/4_content/2/fuvest
#
#
# Bacharelado em Oceanografia (ID 169)
# ../../data/4_content/169/fuvest
#
#
# Bacharelado em Física Computacional (ID 158)
# ../../data/4_content/158/fuvest
#
#
# Química – Bacharelado e Licenciatura – Noturno (Bach. – Ênfase em Química) (ID 172)
# ../../data/4_content/172/fuvest
#
#
# Engenharia Civil (ID 43)
# ../../data/4_content/43/fuvest
#
#
# Medicina Veterinária (ID 138)
# ../../data/4_content/138/fuvest
#
#
# Engenharia Civil (ID 54)
# ../../data/4_content/54/fuvest
#
#
# Terapia Ocupacional (ID 119)
# ../../data/4_content/119/fuvest
#
#
# Química – Bacharelado e Licenciatura – Integral (Bach. – Ênfases: Tecnológica; Biotecnologia; Bioquímica e Biologia Molecular) (ID 171)
# ../../data/4_content/171/fuvest
#
#
# Informática Biomédica (ID 123)
# ../../data/4_content/123/fuvest
#
#
# Bacharelado em Jornalismo (ID 25)
# ../../data/4_content/25/fuvest
#
#
# Engenharia Química (quadrimestral) (ID 64)
# ../../data/4_content/64/fuvest
#
#
# Design (ID 73)
# ../../data/4_content/73/fuvest
#
#
# Bacharelado em Sistemas de Informação (ID 0)
# ../../data/4_content/0/fuvest
#
#
# Engenharia Mecânica (ID 61)
# ../../data/4_content/61/fuvest
#
#
# Ciências Sociais - Bach./Lic. (ID 103)
# ../../data/4_content/103/fuvest
#
#
# Bacharelado em Administração (ID 86)
# ../../data/4_content/86/fuvest
#
#
# Bacharelado em Ciência da Computação (ID 162)
# ../../data/4_content/162/fuvest
#
#
# Engenharia Química (ID 39)
# ../../data/4_content/39/fuvest
#
#
# Estatística - Bacharelado (ID 165)
# ../../data/4_content/165/fuvest
#
#
# Matemática - Bacharelado (ID 166)
# ../../data/4_content/166/fuvest
#
#
# Bacharelado em Gestão Ambiental (ID 10)
# ../../data/4_content/10/fuvest
#
#
# Curso Superior do Audiovisual (ID 29)
# ../../data/4_content/29/fuvest
#
#
# Engenharia de Produção (ID 59)
# ../../data/4_content/59/fuvest
#
#
# Curso de Graduação em Obstetrícia (ID 6)
# ../../data/4_content/6/fuvest
#
#
# Gestão de Políticas Públicas (ID 12)
# ../../data/4_content/12/fuvest
#
#
# Engenharia Mecatrônica (ID 62)
# ../../data/4_content/62/fuvest
#
#
# Ciências Biológicas - Bach./Lic. (ID 143)
# ../../data/4_content/143/fuvest
#
#
# Odontologia (ID 125)
# ../../data/4_content/125/fuvest
#
#
# Biblioteconomia (ID 19)
# ../../data/4_content/19/fuvest
#
#
# Ciências Contábeis - Bach. (ID 88)
# ../../data/4_content/88/fuvest
#
#
# Enfermagem – Bach. e Lic. (ID 35)
# ../../data/4_content/35/fuvest
#
#
# Engenharia de Petróleo (ID 58)
# ../../data/4_content/58/fuvest
#
#
# Enfermagem - Bach. e Lic. (ID 33)
# ../../data/4_content/33/fuvest
#
#
# Bacharelado em Sistemas de Informação (ID 149)
# ../../data/4_content/149/fuvest
#
#
# Engenharia Ambiental (ID 53)
# ../../data/4_content/53/fuvest
#
#
# Medicina (ID 113)
# ../../data/4_content/113/fuvest
#
#
# Engenharia Ambiental (ID 40)
# ../../data/4_content/40/fuvest
#
#
# Ciências Biológicas – Bacharelado e Licenciatura (ID 98)
# ../../data/4_content/98/fuvest
#
#
# Bacharelado em Administração (ID 80)
# ../../data/4_content/80/fuvest
#
#
# Bach. em Matemática Aplicada e Computacional (ID 168)
# ../../data/4_content/168/fuvest
#
#
# Medicina (ID 117)
# ../../data/4_content/117/fuvest
#
#
# Fonoaudiologia (ID 115)
# ../../data/4_content/115/fuvest
#
#
# Bacharelado em Ciências Contábeis (ID 83)
# ../../data/4_content/83/fuvest
#
#
# Engenharia de Computação (ID 52)
# ../../data/4_content/52/fuvest
#
#
# Bacharelado em Ciências Biomédicas (ID 145)
# ../../data/4_content/145/fuvest
#
#
# Pedagogia (ID 99)
# ../../data/4_content/99/fuvest
#
#
# Bacharelado em Administração (ID 71)
# ../../data/4_content/71/fuvest
#
#
# Artes Cênicas - Bach. e Lic. (ID 16)
# ../../data/4_content/16/fuvest
#
#
# Farmácia (ID 74)
# ../../data/4_content/74/fuvest
#
#
# Engenharia Física (ID 42)
# ../../data/4_content/42/fuvest

# %%
fuvest_dir
# Out:
# '../../data/4_content/42/fuvest'

# %%
def read_file_content(filepath):
    with open(filepath, mode='r') as f:
        return f.read()

# %%
def parse_fuvest_content(path):
    latest_metrics_plotly_div = read_file_content(join(path, 'latest_metrics.html'))
    metric_evolution_plotly_div = read_file_content(join(path, 'metric_evolution.html'))
    grade_dict = {}
    for year in listdir(path):
        year_dict = {}
        year_dir = join(path, year)
        if isdir(year_dir):
            for quota_filename in listdir(year_dir):
                quota, _ = splitext(quota_filename)
                year_dict[quota] = read_file_content(join(year_dir, quota_filename))
            grade_dict[year] = year_dict

    return (latest_metrics_plotly_div,
            metric_evolution_plotly_div,
            grade_dict)

# %% [markdown]
# #### Exam selection

# %%
def render_selection(jinja_env, result_dir, course_id, 
                     course_name=None, id_df=None,
                     fuvest=False, enem=False,
                     fuvest_url=None, enem_url=None,
                     template_filename='vestibulares.html.jinja',
                     render_filename='vestibulares'):
    if course_name is None:
        course_name = get_course_name(course_id, id_df)
    selection_template = jinja_env.get_template(template_filename) 
    selection_website = selection_template.render(
        active_link='Notas',
        root_path='../../',
        course_name=course_name,
        render_fuvest=fuvest,
        render_enem=enem,
        fuvest_url=fuvest_url,
        enem_url=enem_url,
        button_text='Acesse as notas')
    selection_path = create_render_save_path(
        result_dir=result_dir,
        course_id=course_id,
        filename=render_filename,
    )
    save_website(selection_website, selection_path)

# %% [markdown]
# #### Course selection

# %%
def render_course_selection(jinja_env, result_dir, 
                            all_courses_dict=None,
                            template_filename='cursos.html.jinja',
                            render_filename='cursos'):
    courses_template = jinja_env.get_template(template_filename) 
    courses_website = courses_template.render(
        active_link='Notas',
        root_path='../',
        all_courses_dict=all_courses_dict)
    courses_path = join(result_dir, render_filename+'.html')
    save_website(courses_website, courses_path)

# %% [markdown]
# #### Final rendering

# %%
def render_courses(content_dir, jinja_env, id_df, result_dir):
    fuvest_template, = read_course_templates(jinja_env)
    render_fuvest = False
    render_enem = False
    all_courses_dict = {}

    for course_id_str in listdir(content_dir):
        course_dir = join(content_dir, course_id_str)
        if isdir(course_dir):
            course_id = int(course_id_str)
            course_name, course_institute = get_course_name_institute(course_id, id_df)
            all_courses_dict[f'{course_institute} - {course_name}'] = join(course_id_str, 'vestibulares.html')

            for exam in listdir(course_dir):
                if exam == 'fuvest':
                    render_fuvest = True
                    fuvest_dir = join(course_dir, 'fuvest')
                    latest_metrics, metric_evolution, grade_dict = parse_fuvest_content(fuvest_dir)
                    fuvest_website = fuvest_template.render(
                        active_link='Notas',
                        root_path='../../../',
                        course_name=course_name,
                        latest_metrics_plotly_div=latest_metrics,
                        metric_evolution_plotly_div=metric_evolution,
                        grade_dict=grade_dict)
                    fuvest_path = create_render_save_path(
                        result_dir=result_dir,
                        course_id=course_id,
                        new_dir='fuvest',
                        filename=course_name,
                    )
                    save_website(fuvest_website, fuvest_path)
                elif exam == 'enem':
                    raise NotImplementedError(f'Only Fuvest results can be parsed at the moment, but directory {course_dir} contained Enem results.')
                else:
                    raise ValueError(f'Unknown exam type inside directory {course_dir}.')

            render_selection(jinja_env, result_dir, course_id, course_name,
                             fuvest=render_fuvest, enem=render_enem,
                             fuvest_url=create_render_save_path(new_dir='fuvest', filename=course_name),
                             enem_url=create_render_save_path(new_dir='enem', filename=course_name),
            )
            render_course_selection(jinja_env, result_dir,
                                    all_courses_dict=all_courses_dict)

# %%
render_courses(CONTENT_DIR, JINJA_ENV, ID_DF, GRADES_RESULT_DIR)

# %%
# !rm -rf ../../website/notas/*

# %% [markdown]
# ### Essays

# %% [markdown]
# #### Lists

# %%
def join_essay_files(exam, essays_dir):
    essay_dir = join(essays_dir, exam)
    essay_filenames = listdir(essay_dir)
    essays_list = []
    for essay_filename in essay_filenames:
        essay_path = join(essay_dir, essay_filename)
        essays_list.append(pd.read_csv(essay_path).convert_dtypes())
    return pd.concat(essays_list, axis=0)

# %%
enem_essays = join_essay_files('enem', ESSAYS_DIR)
enem_essays
# Out:
#      ano  nota   c1   c2   c3   c4   c5                           drive_id  \
# 0   2018   920  180  180  200  180  180  1_i2icBmoym3I6tVwZiiBngcKrA6LbaZO
# 1   2021   760  160  120  140  160  180  1QOdWS15kBgfka8HrXcjiXdHoUOV9Keu1
# 2   2021   920  140  200  200  200  180  1__sggpQa_zAn_iacA9_YhhY4KZ7JtnTL
# 3   2021   980  180  200  200  200  200  17FC_gqSN42JAGxEGPZkbw_y3GfOgKFNm
# 0   2020   920  160  200  160  200  200  1CA5BuMVUlOGedcrzcyfSHRhuU2ksJCOk
# ..   ...   ...  ...  ...  ...  ...  ...                                ...
# 8   2021   940  160  200  180  200  200  1U9HdVZr11EtPXX0Y1Z8cVsSPKLV24_W_
# 9   2021   940  160  200  180  200  200  19acd7zWYTzFQME3otPJheoPu01He4Ocn
# 10  2020   660  140  120  160  120  120  1rZWD5yrcsR35tK3bzpZY-sCgjP074VoB
# 11  2021   960  160  200  200  200  200  1hokIHwjrd4cIfhchfARGYg0o0K2mDgea
# 12  2021   940  160  200  200  180  200  1Ltxa6YhHde1S1vNlo4FSIkU0PQSRzHd7
#
#                                                   url
# 0   https://drive.google.com/file/d/1_i2icBmoym3I6...
# 1   https://drive.google.com/file/d/1QOdWS15kBgfka...
# 2   https://drive.google.com/file/d/1__sggpQa_zAn_...
# 3   https://drive.google.com/file/d/17FC_gqSN42JAG...
# 0   https://drive.google.com/file/d/1CA5BuMVUlOGed...
# ..                                                ...
# 8   https://drive.google.com/file/d/1U9HdVZr11EtPX...
# 9   https://drive.google.com/file/d/19acd7zWYTzFQM...
# 10  https://drive.google.com/file/d/1rZWD5yrcsR35t...
# 11  https://drive.google.com/file/d/1hokIHwjrd4cIf...
# 12  https://drive.google.com/file/d/1Ltxa6YhHde1S1...
#
# [94 rows x 9 columns]

# %%
fuvest_essays = join_essay_files('fuvest', ESSAYS_DIR)
fuvest_essays
# Out:
#       ano  nota                           drive_id  \
# 0    2018  36.5  1ThLLNWnUHgGq55ElFVUFVysSem8o83HY
# 1    2018  33.0  1J6c8CNdx6Yy1ye0gK8DLo1Oo3yUL3DLK
# 2    2020  38.5  1pJ5_z-00dpX4mbsPSzUsLX4pKFuWE434
# 3    2020  42.0  1p2WISpPRTiRxxb8uzyyf3Qbkd2OgkaiS
# 4    2020  43.0  1y0lhK2DInBrNr29fNcmR1jUo3SZKhjZU
# ..    ...   ...                                ...
# 289  2021  35.0  1thKrNuHXwK2HIOFNh-Q8dVZI9XPQuR3J
# 290  2021  47.0  19HoxizBATvv4J5_2cROZHGwtlH33Ip98
# 291  2021  39.5  13THXqRzCQowVPwormQEy0uMtGuZZ5e9e
# 292  2021  38.0  1E1P5VKDYPb3hTIatGLg37bB86TW0HO0V
# 293  2021  33.0  1zz50VG5Uyr6I3t-36v2YyT0Ez_JTA1-z
#
#                                                    url
# 0    https://drive.google.com/file/d/1ThLLNWnUHgGq5...
# 1    https://drive.google.com/file/d/1J6c8CNdx6Yy1y...
# 2    https://drive.google.com/file/d/1pJ5_z-00dpX4m...
# 3    https://drive.google.com/file/d/1p2WISpPRTiRxx...
# 4    https://drive.google.com/file/d/1y0lhK2DInBrNr...
# ..                                                 ...
# 289  https://drive.google.com/file/d/1thKrNuHXwK2HI...
# 290  https://drive.google.com/file/d/19HoxizBATvv4J...
# 291  https://drive.google.com/file/d/13THXqRzCQowVP...
# 292  https://drive.google.com/file/d/1E1P5VKDYPb3hT...
# 293  https://drive.google.com/file/d/1zz50VG5Uyr6I3...
#
# [426 rows x 4 columns]

# %%
def build_years_dict(essays_df):
    years_dict = {}
    for year, essays in essays_df.groupby('ano'):
        essays_dict = {} 
        for _, essay_series in essays.iterrows():
            essays_dict[essay_series['nota']] = essay_series.to_dict()
        years_dict[year] = essays_dict
    return years_dict

# %%
build_years_dict(enem_essays)
# Out:
# {2016: {820: {'ano': 2016,
#    'nota': 820,
#    'c1': 160,
#    'c2': 160,
#    'c3': 160,
#    'c4': 180,
#    'c5': 160,
#    'drive_id': '1z8-2IDtPjCJx6PFc0_y0iMQczx5N33dN',
#    'url': 'https://drive.google.com/file/d/1z8-2IDtPjCJx6PFc0_y0iMQczx5N33dN/view'}},
#  2018: {920: {'ano': 2018,
#    'nota': 920,
#    'c1': <NA>,
#    'c2': <NA>,
#    'c3': <NA>,
#    'c4': <NA>,
#    'c5': <NA>,
#    'drive_id': '1AyoH4ZogqtuI64BSZ6HCaRqRE2iePT_V',
#    'url': 'https://drive.google.com/file/d/1AyoH4ZogqtuI64BSZ6HCaRqRE2iePT_V/view'},
#   940: {'ano': 2018,
#    'nota': 940,
#    'c1': 180,
#    'c2': 200,
#    'c3': 180,
#    'c4': 180,
#    'c5': 200,
#    'drive_id': '1TUqOsxw6tigBab-UlxT1BanTA-54saq_',
#    'url': 'https://drive.google.com/file/d/1TUqOsxw6tigBab-UlxT1BanTA-54saq_/view'},
#   960: {'ano': 2018,
#    'nota': 960,
#    'c1': 180,
#    'c2': 200,
#    'c3': 180,
#    'c4': 200,
#    'c5': 200,
#    'drive_id': '1oV7r3jxg7-KqX7wAF5YyD_hL24v01Rzu',
#    'url': 'https://drive.google.com/file/d/1oV7r3jxg7-KqX7wAF5YyD_hL24v01Rzu/view'},
#   980: {'ano': 2018,
#    'nota': 980,
#    'c1': 180,
#    'c2': 200,
#    'c3': 200,
#    'c4': 200,
#    'c5': 200,
#    'drive_id': '1XOuEHypoouzLPy13SGpymM8lKNZ7UTtg',
#    'url': 'https://drive.google.com/file/d/1XOuEHypoouzLPy13SGpymM8lKNZ7UTtg/view'}},
#  2019: {900: {'ano': 2019,
#    'nota': 900,
#    'c1': 160,
#    'c2': 200,
#    'c3': 200,
#    'c4': 160,
#    'c5': 180,
#    'drive_id': '1JCZrzP4ZAAMkmV6usdnrL8ppbS8qePQV',
#    'url': 'https://drive.google.com/file/d/1JCZrzP4ZAAMkmV6usdnrL8ppbS8qePQV/view'},
#   920: {'ano': 2019,
#    'nota': 920,
#    'c1': 180,
#    'c2': 180,
#    'c3': 180,
#    'c4': 180,
#    'c5': 200,
#    'drive_id': '1S6AINcBoapgVZPDIWTTwwfrsIzAUjgmR',
#    'url': 'https://drive.google.com/file/d/1S6AINcBoapgVZPDIWTTwwfrsIzAUjgmR/view'},
#   960: {'ano': 2019,
#    'nota': 960,
#    'c1': 160,
#    'c2': 200,
#    'c3': 200,
#    'c4': 200,
#    'c5': 200,
#    'drive_id': '1FjlpmOtfO9KeiwnlTCDqtgxnaOxDCKxL',
#    'url': 'https://drive.google.com/file/d/1FjlpmOtfO9KeiwnlTCDqtgxnaOxDCKxL/view'},
#   720: {'ano': 2019,
#    'nota': 720,
#    'c1': 120,
#    'c2': 180,
#    'c3': 140,
#    'c4': 120,
#    'c5': 160,
#    'drive_id': '1H6Hx-S4bftdwpge_ExUhDTNQ3y9jizXI',
#    'url': 'https://drive.google.com/file/d/1H6Hx-S4bftdwpge_ExUhDTNQ3y9jizXI/view'},
#   740: {'ano': 2019,
#    'nota': 740,
#    'c1': 140,
#    'c2': 120,
#    'c3': 160,
#    'c4': 120,
#    'c5': 200,
#    'drive_id': '1AA1bHrmhjcYFS4WFnc9CZAASE83e70wR',
#    'url': 'https://drive.google.com/file/d/1AA1bHrmhjcYFS4WFnc9CZAASE83e70wR/view'},
#   940: {'ano': 2019,
#    'nota': 940,
#    'c1': 160,
#    'c2': 180,
#    'c3': 200,
#    'c4': 200,
#    'c5': 200,
#    'drive_id': '1d7yiTVKeF_gpSA_9mJsAAWF2q6rv6qKo',
#    'url': 'https://drive.google.com/file/d/1d7yiTVKeF_gpSA_9mJsAAWF2q6rv6qKo/view'},
#   980: {'ano': 2019,
#    'nota': 980,
#    'c1': 180,
#    'c2': 200,
#    'c3': 200,
#    'c4': 200,
#    'c5': 200,
#    'drive_id': '116AOmvG3rzRUmikXYOyBJTjvWIpzDSRM',
#    'url': 'https://drive.google.com/file/d/116AOmvG3rzRUmikXYOyBJTjvWIpzDSRM/view'},
#   800: {'ano': 2019,
#    'nota': 800,
#    'c1': 140,
#    'c2': 200,
#    'c3': 160,
#    'c4': 140,
#    'c5': 160,
#    'drive_id': '1598BiaT1_3bz2vAQ1DtshQc9LEVWcQre',
#    'url': 'https://drive.google.com/file/d/1598BiaT1_3bz2vAQ1DtshQc9LEVWcQre/view'},
#   880: {'ano': 2019,
#    'nota': 880,
#    'c1': 160,
#    'c2': 180,
#    'c3': 200,
#    'c4': 180,
#    'c5': 160,
#    'drive_id': '154-xrk5XA5FjtvgJxAkCG-2dLWZLwp0s',
#    'url': 'https://drive.google.com/file/d/154-xrk5XA5FjtvgJxAkCG-2dLWZLwp0s/view'},
#   840: {'ano': 2019,
#    'nota': 840,
#    'c1': 140,
#    'c2': 180,
#    'c3': 160,
#    'c4': 180,
#    'c5': 180,
#    'drive_id': '1YrWMfyafkwtj7RWuXCaAKaqsFjU3Oofu',
#    'url': 'https://drive.google.com/file/d/1YrWMfyafkwtj7RWuXCaAKaqsFjU3Oofu/view'}},
#  2020: {920: {'ano': 2020,
#    'nota': 920,
#    'c1': 200,
#    'c2': 200,
#    'c3': 180,
#    'c4': 140,
#    'c5': 200,
#    'drive_id': '13ZaqGkZc8_CXor3Mf6FqeL6d6Enz0SVL',
#    'url': 'https://drive.google.com/file/d/13ZaqGkZc8_CXor3Mf6FqeL6d6Enz0SVL/view'},
#   960: {'ano': 2020,
#    'nota': 960,
#    'c1': <NA>,
#    'c2': <NA>,
#    'c3': <NA>,
#    'c4': <NA>,
#    'c5': <NA>,
#    'drive_id': '1KMUjWmAvDhZ1KptJ-RQxb6Ib7wPBjJd8',
#    'url': 'https://drive.google.com/file/d/1KMUjWmAvDhZ1KptJ-RQxb6Ib7wPBjJd8/view'},
#   900: {'ano': 2020,
#    'nota': 900,
#    'c1': 160,
#    'c2': 160,
#    'c3': 180,
#    'c4': 200,
#    'c5': 200,
#    'drive_id': '1jyKdt5FyBA1vJtSdyr9GoZM-CWy-Kcqk',
#    'url': 'https://drive.google.com/file/d/1jyKdt5FyBA1vJtSdyr9GoZM-CWy-Kcqk/view'},
#   860: {'ano': 2020,
#    'nota': 860,
#    'c1': 160,
#    'c2': 180,
#    'c3': 160,
#    'c4': 180,
#    'c5': 180,
#    'drive_id': '19hj3rw7T_P3UQ1Dv9eztaZdhP-2n9ccc',
#    'url': 'https://drive.google.com/file/d/19hj3rw7T_P3UQ1Dv9eztaZdhP-2n9ccc/view'},
#   940: {'ano': 2020,
#    'nota': 940,
#    'c1': 180,
#    'c2': 200,
#    'c3': 200,
#    'c4': 180,
#    'c5': 180,
#    'drive_id': '1dBD_sURnW8quaMWJ1SYCXJ-bHbdjKSIQ',
#    'url': 'https://drive.google.com/file/d/1dBD_sURnW8quaMWJ1SYCXJ-bHbdjKSIQ/view'},
#   880: {'ano': 2020,
#    'nota': 880,
#    'c1': 160,
#    'c2': 200,
#    'c3': 160,
#    'c4': 200,
#    'c5': 160,
#    'drive_id': '1NzpQScERaeTPhclNIa7lUmTIgpHXF2XC',
#    'url': 'https://drive.google.com/file/d/1NzpQScERaeTPhclNIa7lUmTIgpHXF2XC/view'},
#   800: {'ano': 2020,
#    'nota': 800,
#    'c1': 160,
#    'c2': 180,
#    'c3': 140,
#    'c4': 160,
#    'c5': 160,
#    'drive_id': '1tiMySLq2qyp4AcyO6v9_ZOPaIR8GOSBY',
#    'url': 'https://drive.google.com/file/d/1tiMySLq2qyp4AcyO6v9_ZOPaIR8GOSBY/view'},
#   980: {'ano': 2020,
#    'nota': 980,
#    'c1': 180,
#    'c2': 200,
#    'c3': 200,
#    'c4': 200,
#    'c5': 200,
#    'drive_id': '1cwqtAmVzEmV0IzBcvAr9QezH7MjUgHcF',
#    'url': 'https://drive.google.com/file/d/1cwqtAmVzEmV0IzBcvAr9QezH7MjUgHcF/view'},
#   840: {'ano': 2020,
#    'nota': 840,
#    'c1': 140,
#    'c2': 180,
#    'c3': 160,
#    'c4': 180,
#    'c5': 180,
#    'drive_id': '1m526zzzAR0KcYI2Y2o5bCCHXAiysV9F8',
#    'url': 'https://drive.google.com/file/d/1m526zzzAR0KcYI2Y2o5bCCHXAiysV9F8/view'},
#   820: {'ano': 2020,
#    'nota': 820,
#    'c1': 160,
#    'c2': 180,
#    'c3': 160,
#    'c4': 160,
#    'c5': 160,
#    'drive_id': '1ZVALeAnYxOqqnAe2Vt2JlUpOfCjIQkOp',
#    'url': 'https://drive.google.com/file/d/1ZVALeAnYxOqqnAe2Vt2JlUpOfCjIQkOp/view'},
#   660: {'ano': 2020,
#    'nota': 660,
#    'c1': 140,
#    'c2': 120,
#    'c3': 160,
#    'c4': 120,
#    'c5': 120,
#    'drive_id': '1rZWD5yrcsR35tK3bzpZY-sCgjP074VoB',
#    'url': 'https://drive.google.com/file/d/1rZWD5yrcsR35tK3bzpZY-sCgjP074VoB/view'}},
#  2021: {760: {'ano': 2021,
#    'nota': 760,
#    'c1': 160,
#    'c2': 120,
#    'c3': 140,
#    'c4': 160,
#    'c5': 180,
#    'drive_id': '1QOdWS15kBgfka8HrXcjiXdHoUOV9Keu1',
#    'url': 'https://drive.google.com/file/d/1QOdWS15kBgfka8HrXcjiXdHoUOV9Keu1/view?usp=sharing'},
#   920: {'ano': 2021,
#    'nota': 920,
#    'c1': 160,
#    'c2': 200,
#    'c3': 180,
#    'c4': 180,
#    'c5': 200,
#    'drive_id': '1S1oSJ2SWuVatCSnwrCvMPbWtjD8_PQBc',
#    'url': 'https://drive.google.com/file/d/1S1oSJ2SWuVatCSnwrCvMPbWtjD8_PQBc/view'},
#   980: {'ano': 2021,
#    'nota': 980,
#    'c1': 180,
#    'c2': 200,
#    'c3': 200,
#    'c4': 200,
#    'c5': 200,
#    'drive_id': '1TiLakiML9k0x7LGpQh69yqFYEPYDBEpS',
#    'url': 'https://drive.google.com/file/d/1TiLakiML9k0x7LGpQh69yqFYEPYDBEpS/view'},
#   940: {'ano': 2021,
#    'nota': 940,
#    'c1': 160,
#    'c2': 200,
#    'c3': 200,
#    'c4': 180,
#    'c5': 200,
#    'drive_id': '1Ltxa6YhHde1S1vNlo4FSIkU0PQSRzHd7',
#    'url': 'https://drive.google.com/file/d/1Ltxa6YhHde1S1vNlo4FSIkU0PQSRzHd7/view'},
#   960: {'ano': 2021,
#    'nota': 960,
#    'c1': 160,
#    'c2': 200,
#    'c3': 200,
#    'c4': 200,
#    'c5': 200,
#    'drive_id': '1hokIHwjrd4cIfhchfARGYg0o0K2mDgea',
#    'url': 'https://drive.google.com/file/d/1hokIHwjrd4cIfhchfARGYg0o0K2mDgea/view'}}}

# %%
ESSAY_TEMPLATE = JINJA_ENV.get_template('redacoes.html.jinja')
with open('enem.html', 'w') as f:
    f.write(ESSAY_TEMPLATE.render(
        years_dict=build_years_dict(enem_essays),
        exam='Enem',
        criteria=['c1', 'c2', 'c3', 'c4', 'c5'],
        active_link='Redações',
        root_path='../'))

# %%
ESSAY_TEMPLATE = JINJA_ENV.get_template('redacoes.html.jinja')
with open('fuvest.html', 'w') as f:
    f.write(ESSAY_TEMPLATE.render(
        years_dict=build_years_dict(fuvest_essays),
        exam='Fuvest',
        active_link='Redações',
        root_path='../'))

# %% [markdown]
# #### Exam selection

# %%
SELECTION_TEMPLATE = JINJA_ENV.get_template('vestibulares.html.jinja')
selection_website = SELECTION_TEMPLATE.render(
    active_link='Redações',
    root_path='../',
    render_fuvest=True,
    render_enem=True,
    fuvest_url='fuvest.html',
    enem_url='enem.html',
    button_text='Acesse as redações')
save_website(selection_website, 'example_selection.html')

# %% [markdown]
# #### Final rendering

# %%
def render_essays(jinja_env, essays_dir, result_dir,
                  essay_template_filename='redacoes.html.jinja',
                  selection_template_filename='vestibulares.html.jinja'):
    for exam in ['enem', 'fuvest']:
        exam_essays = join_essay_files(exam, essays_dir)
        years_dict = build_years_dict(exam_essays)
        criteria = None
        if exam == 'enem':
            criteria = ['c1', 'c2', 'c3', 'c4', 'c5'],
        
        essay_template = jinja_env.get_template(essay_template_filename)
        essay_website = essay_template.render(
            years_dict=years_dict,
            exam=exam,
            criteria=criteria,
            active_link='Redações',
            root_path='../')
        save_website(essay_website, join(result_dir, exam+'.html'))
    
    selection_template = jinja_env.get_template(selection_template_filename)
    selection_website = selection_template.render(
        active_link='Redações',
        root_path='../',
        render_fuvest=True,
        render_enem=True,
        fuvest_url='fuvest.html',
        enem_url='enem.html',
        button_text='Acesse as redações')
    save_website(selection_website, join(result_dir, 'vestibulares.html'))

# %%
render_essays(JINJA_ENV, ESSAYS_DIR, ESSAYS_RESULT_DIR)

# %%
# !rm -rf ../../website/redacoes/*
